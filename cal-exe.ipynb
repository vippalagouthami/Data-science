# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfc=pd.read_csv(r"C:\Users\Legion\OneDrive\Desktop\data\Calories Burn Dataset\Calories Burn Dataset\calories.csv")

# %%
dfc
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
dfe=pd.read_csv(r"C:\Users\Legion\OneDrive\Desktop\data\Calories Burn Dataset\Calories Burn Dataset\exercise.csv")

# %%
dfe
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
dfec=pd.merge(dfe,dfc)

# %%
dfec
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
dfec.drop("User_ID",axis=1,inplace=True)

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
sns.boxplot(dfec["Height"])
# Out:
# <Axes: >

# %%
sns.boxplot(dfec["Weight"])
# Out:
# <Axes: >

# %%
sns.boxplot(dfec["Heart_Rate"])
# Out:
# <Axes: >

# %%
sns.boxplot(dfec["Body_Temp"])
# Out:
# <Axes: >

# %%
sns.distplot(dfec["Height"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20716\481803563.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfec["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(dfec["Weight"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20716\1031489497.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfec["Weight"])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(dfec["Heart_Rate"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20716\3450211675.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfec["Heart_Rate"])
# <Axes: xlabel='Heart_Rate', ylabel='Density'>

# %%
sns.distplot(dfec["Body_Temp"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20716\2665767685.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfec["Body_Temp"])
# <Axes: xlabel='Body_Temp', ylabel='Density'>

# %%
dfec["Height"].skew()
# Out:
# -0.006189620437893538

# %%
dfec["Weight"].skew()
# Out:
# 0.22672530725814513

# %%
dfec["Heart_Rate"].skew()
# Out:
# -0.01070407972854895

# %%
dfec["Body_Temp"].skew()
# Out:
# -0.9943824155974582

# %% [markdown]
# error detection for Height

# %%
m=dfec["Height"].mean()

# %%
m
# Out:
# 174.46513333333334

# %%
s=dfec["Height"].std()

# %%
s
# Out:
# 14.2581136165512

# %%
l=m-3*s

# %%
l
# Out:
# 131.69079248367973

# %%
u=m+3*s

# %%
u
# Out:
# 217.23947418298695

# %%
dfec[dfec["Height"]<l]
# Out:
#       Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 4200  female   63   123.0    40.0       9.0        97.0       39.9      55.0
# 6226  female   58   127.0    40.0      29.0       102.0       40.8     189.0
# 7774  female   30   126.0    39.0      25.0       104.0       40.7     156.0

# %%
dfec[dfec["Height"]>u]
# Out:
#       Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 6711    male   40   218.0   132.0       1.0        88.0       37.8       5.0
# 10362   male   22   222.0   128.0       6.0        84.0       39.3      20.0
# 12189   male   21   219.0   126.0      15.0        97.0       40.4      78.0
# 12360   male   41   218.0   119.0      18.0        85.0       40.2      76.0

# %%
dfec[(dfec["Height"]<l)|(dfec["Height"]>u)]
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 4200   female   63   123.0    40.0       9.0        97.0       39.9      55.0
# 6226   female   58   127.0    40.0      29.0       102.0       40.8     189.0
# 6711     male   40   218.0   132.0       1.0        88.0       37.8       5.0
# 7774   female   30   126.0    39.0      25.0       104.0       40.7     156.0
# 10362    male   22   222.0   128.0       6.0        84.0       39.3      20.0
# 12189    male   21   219.0   126.0      15.0        97.0       40.4      78.0
# 12360    male   41   218.0   119.0      18.0        85.0       40.2      76.0

# %%
dfec["Height"].map(lambda x:l if x<l else u if x>u else x)
# Out:
# 0        190.0
# 1        166.0
# 2        179.0
# 3        179.0
# 4        154.0
#          ...
# 14995    193.0
# 14996    165.0
# 14997    159.0
# 14998    193.0
# 14999    173.0
# Name: Height, Length: 15000, dtype: float64

# %%
dfec["Height"]=dfec["Height"].map(lambda x:l if x<l else u if x>u else x)

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
dfec[(dfec["Height"]<l)|(dfec["Height"]>u)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %%
m1=dfec["Weight"].mean()

# %%
m1
# Out:
# 74.96686666666666

# %%
s1=dfec["Weight"].std()

# %%
s1
# Out:
# 15.035656739246951

# %%
l1=m1-3*s1

# %%
l1
# Out:
# 29.85989644892581

# %%
u1=m1+3*s1

# %%
u1
# Out:
# 120.07383688440751

# %%
dfec[dfec["Weight"]<l1]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %%
dfec[dfec["Weight"]>u1]
# Out:
#       Gender  Age      Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 1909    male   67  212.000000   124.0      16.0        87.0       40.1
# 3490    male   57  210.000000   122.0       5.0        80.0       39.2
# 5177    male   39  208.000000   121.0       6.0        77.0       39.2
# 5662    male   73  213.000000   121.0      27.0       112.0       40.9
# 6578    male   72  211.000000   121.0      27.0       108.0       40.7
# 6711    male   40  217.239474   132.0       1.0        88.0       37.8
# 8527    male   71  210.000000   121.0      25.0       111.0       40.6
# 10362   male   22  217.239474   128.0       6.0        84.0       39.3
# 10926   male   71  210.000000   121.0       6.0        94.0       39.1
# 12189   male   21  217.239474   126.0      15.0        97.0       40.4
# 13276   male   55  217.000000   126.0      17.0        91.0       40.4
# 13806   male   43  214.000000   124.0      17.0       103.0       40.7
# ...

# %%
dfec[(dfec["Weight"]<l1)|(dfec["Weight"]>u1)]
# Out:
#       Gender  Age      Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 1909    male   67  212.000000   124.0      16.0        87.0       40.1
# 3490    male   57  210.000000   122.0       5.0        80.0       39.2
# 5177    male   39  208.000000   121.0       6.0        77.0       39.2
# 5662    male   73  213.000000   121.0      27.0       112.0       40.9
# 6578    male   72  211.000000   121.0      27.0       108.0       40.7
# 6711    male   40  217.239474   132.0       1.0        88.0       37.8
# 8527    male   71  210.000000   121.0      25.0       111.0       40.6
# 10362   male   22  217.239474   128.0       6.0        84.0       39.3
# 10926   male   71  210.000000   121.0       6.0        94.0       39.1
# 12189   male   21  217.239474   126.0      15.0        97.0       40.4
# 13276   male   55  217.000000   126.0      17.0        91.0       40.4
# 13806   male   43  214.000000   124.0      17.0       103.0       40.7
# ...

# %%
dfec["Weight"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)
# Out:
# 0        94.0
# 1        60.0
# 2        79.0
# 3        71.0
# 4        58.0
#          ...
# 14995    86.0
# 14996    65.0
# 14997    58.0
# 14998    97.0
# 14999    79.0
# Name: Weight, Length: 15000, dtype: float64

# %%
dfec["Weight"]=dfec["Weight"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
m2=dfec["Heart_Rate"].mean()

# %%
m2
# Out:
# 95.51853333333334

# %%
s2=dfec["Heart_Rate"].std()

# %%
s2
# Out:
# 9.583328189839209

# %%
l2=m2-3*s2

# %%
l2
# Out:
# 66.76854876381572

# %%
u2=m2+3*s2

# %%
u2
# Out:
# 124.26851790285096

# %%
dfec[dfec["Heart_Rate"]<l2]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %%
dfec[dfec["Heart_Rate"]>u2]
# Out:
#      Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 3357   male   65   189.0    98.0      27.0       125.0       40.9     295.0
# 5097   male   31   171.0    75.0      27.0       125.0       40.7     237.0
# 9981   male   32   188.0    91.0      30.0       128.0       40.9     289.0

# %%
dfec[(dfec["Heart_Rate"]<l2)|(dfec["Heart_Rate"]>u2)]
# Out:
#      Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 3357   male   65   189.0    98.0      27.0       125.0       40.9     295.0
# 5097   male   31   171.0    75.0      27.0       125.0       40.7     237.0
# 9981   male   32   188.0    91.0      30.0       128.0       40.9     289.0

# %%
dfec["Heart_Rate"].map(lambda x:l2 if x<l2 else u2 if x>u2 else x)
# Out:
# 0        105.0
# 1         94.0
# 2         88.0
# 3        100.0
# 4         81.0
#          ...
# 14995     92.0
# 14996     85.0
# 14997     90.0
# 14998     84.0
# 14999     92.0
# Name: Heart_Rate, Length: 15000, dtype: float64

# %%
dfec["Heart_Rate"]=dfec["Heart_Rate"].map(lambda x:l2 if x<l2 else u2 if x>u2 else x)

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
m3=dfec["Body_Temp"].mean()

# %%
m3
# Out:
# 40.02545333333334

# %%
s3=dfec["Body_Temp"].std()

# %%
s3
# Out:
# 0.7792299239893905

# %%
l3=m3-3*s3

# %%
l3
# Out:
# 37.687763561365166

# %%
u3=m3+3*s3

# %%
u3
# Out:
# 42.36314310530151

# %%
dfec[dfec["Body_Temp"]<l3]
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 301    female   31   169.0    69.0       1.0        74.0       37.6       3.0
# 906      male   22   198.0    97.0       1.0        79.0       37.5       2.0
# 1198   female   68   158.0    60.0       1.0        84.0       37.5       4.0
# 1446     male   36   181.0    85.0       1.0        85.0       37.4       3.0
# 1634   female   54   167.0    65.0       1.0        80.0       37.6       4.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14147  female   59   149.0    50.0       1.0        70.0       37.5       3.0
# 14382  female   34   175.0    71.0       1.0        86.0       37.4       4.0
# 14515  female   51   175.0    67.0       1.0        77.0       37.4       3.0
# 14669  female   30   154.0    55.0       1.0        86.0       37.5       4.0
# 14900    male   43   180.0    79.0       1.0        78.0       37.4       2.0
#
# [76 rows x 8 columns]

# %%
dfec[dfec["Body_Temp"]>u3]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %%
dfec[(dfec["Body_Temp"]<l3)|(dfec["Body_Temp"]>u3)]
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 301    female   31   169.0    69.0       1.0        74.0       37.6       3.0
# 906      male   22   198.0    97.0       1.0        79.0       37.5       2.0
# 1198   female   68   158.0    60.0       1.0        84.0       37.5       4.0
# 1446     male   36   181.0    85.0       1.0        85.0       37.4       3.0
# 1634   female   54   167.0    65.0       1.0        80.0       37.6       4.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14147  female   59   149.0    50.0       1.0        70.0       37.5       3.0
# 14382  female   34   175.0    71.0       1.0        86.0       37.4       4.0
# 14515  female   51   175.0    67.0       1.0        77.0       37.4       3.0
# 14669  female   30   154.0    55.0       1.0        86.0       37.5       4.0
# 14900    male   43   180.0    79.0       1.0        78.0       37.4       2.0
#
# [76 rows x 8 columns]

# %%
dfec["Body_Temp"].map(lambda x:l3 if x<l3 else u3 if x>u3 else x )
# Out:
# 0        40.8
# 1        40.3
# 2        38.7
# 3        40.5
# 4        39.8
#          ...
# 14995    40.4
# 14996    39.2
# 14997    40.1
# 14998    38.3
# 14999    40.5
# Name: Body_Temp, Length: 15000, dtype: float64

# %%
dfec["Body_Temp"]=dfec["Body_Temp"].map(lambda x:l3 if x<l3 else u3 if x>u3 else x )

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
sns.boxplot(dfec["Calories"])
# Out:
# <Axes: >

# %%
sns.distplot(dfec["Calories"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20716\749351077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfec["Calories"])
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
dfec["Calories"].skew()
# Out:
# 0.5053713740451047

# %%
np.round(dfec["Calories"].skew())
# Out:
# 1.0

# %% [markdown]
# Error for Calories in IQR

# %%
q1=dfec["Calories"].quantile(0.25)

# %%
q1
# Out:
# 35.0

# %%
q3=dfec["Calories"].quantile(0.75)

# %%
q3
# Out:
# 138.0

# %%
IQR=q3-q1

# %%
l4=q1-(1.5*IQR)

# %%
l4
# Out:
# -119.5

# %%
u4=q3+(1.5*IQR)

# %%
u4
# Out:
# 292.5

# %%
dfec[dfec["Calories"]<l4]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %%
dfec[(dfec["Calories"]<l4)|(dfec["Calories"]>u4)]
# Out:
#       Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 428     male   75   199.0   103.0      28.0  123.000000       40.5     314.0
# 3357    male   65   189.0    98.0      27.0  124.268518       40.9     295.0
# 6240    male   69   193.0    90.0      29.0  121.000000       41.1     300.0
# 13871   male   75   178.0    76.0      29.0  120.000000       40.8     295.0

# %%
dfec["Calories"].map(lambda x:l4 if x<l4 else u4 if x>u4 else x )
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
dfec["Calories"]=dfec["Calories"].map(lambda x:l4 if x<l4 else u4 if x>u4 else x )

# %%
dfec
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
pd.get_dummies(dfec,drop_first=True)
# Out:
#        Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# 0       68   190.0    94.0      29.0       105.0       40.8     231.0
# 1       20   166.0    60.0      14.0        94.0       40.3      66.0
# 2       69   179.0    79.0       5.0        88.0       38.7      26.0
# 3       34   179.0    71.0      13.0       100.0       40.5      71.0
# 4       27   154.0    58.0      10.0        81.0       39.8      35.0
# ...    ...     ...     ...       ...         ...        ...       ...
# 14995   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999   63   173.0    79.0      18.0        92.0       40.5      98.0
#
#        Gender_male
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ...

# %%
dfec=pd.get_dummies(dfec,drop_first=True)

# %%
X=dfec.drop("Calories",axis=1)

# %%
X
# Out:
#        Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Gender_male
# 0       68   190.0    94.0      29.0       105.0       40.8            1
# 1       20   166.0    60.0      14.0        94.0       40.3            0
# 2       69   179.0    79.0       5.0        88.0       38.7            1
# 3       34   179.0    71.0      13.0       100.0       40.5            0
# 4       27   154.0    58.0      10.0        81.0       39.8            0
# ...    ...     ...     ...       ...         ...        ...          ...
# 14995   20   193.0    86.0      11.0        92.0       40.4            0
# 14996   27   165.0    65.0       6.0        85.0       39.2            0
# 14997   43   159.0    58.0      16.0        90.0       40.1            0
# 14998   78   193.0    97.0       2.0        84.0       38.3            1
# 14999   63   173.0    79.0      18.0        92.0       40.5            1
#
# [15000 rows x 7 columns]

# %%
y=dfec["Calories"]

# %%
y
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((15000, 7), (12000, 7), (3000, 7))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((15000,), (12000,), (3000,))

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
dtree1=DecisionTreeRegressor()
svm1=SVR()
rfr1=RandomForestRegressor()
ada1=AdaBoostRegressor()
grad1=GradientBoostingRegressor()
xgb1=XGBRegressor()
lreg1=LinearRegression()
knn1=KNeighborsRegressor()
clist=[dtree1,svm1,rfr1,ada1,grad1,xgb1,lreg1,knn1]

# %%
clist
# Out:
# [DecisionTreeRegressor(),
#  SVR(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor(),
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  LinearRegression(),
#  KNeighborsRegressor()]

# %%
import time
for i in clist:
    print(i,end="==>")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    m.__class__.__name_
    print(m)
    time.sleep(1)
# Out:
# DecisionTreeRegressor()==>0.9928091480743154
# SVR()==>0.9383673067685319
# RandomForestRegressor()==>0.9982467689475824
# AdaBoostRegressor()==>0.9662916842658587
# GradientBoostingRegressor()==>0.9963373859788731
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
# ...

# %%
for m in clist:
        print(m,end="==>")  
        rlist=[]
        for i in range (0,51):
            print("random_state=",i)
            X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
            m.fit(X_train,y_train)
            s=m.score(X_test,y_test)
            print(s)
            rlist.append(s) 
print("--------------------------------------------------------------------------")
print("Max =",max(rlist)) 
rlist.index(max(rlist))
print("Max_index=",rlist.index(max(rlist)))
print("---------------------------------------------------------------------------")
# Out:
# DecisionTreeRegressor()==>random_state= 0
# 0.9931138893396081
# random_state= 1
# 0.9926438652273065
# random_state= 2
# 0.9927532608441547
# random_state= 3
# 0.9922733816121552
# random_state= 4
# 0.9929915608279042
# random_state= 5
# 0.993064245439366
# random_state= 6
# 0.9932706580693417
# random_state= 7
# 0.9925803395069067
# random_state= 8
# 0.9928784828566359
# random_state= 9
# 0.992544137012314
# random_state= 10
# 0.9935815672463865
# random_state= 11
# 0.9930727314892249
# random_state= 12
# 0.993242558034849
# random_state= 13
# 0.9928336715271919
# random_state= 14
# 0.9928032118996897
# random_state= 15
# 0.9931649571372277
# random_state= 16
# 0.992920719124435
# random_state= 17
# 0.9929368350252603
# random_state= 18
# 0.9925487592714773
# random_state= 19
# 0.9928113669518094
# random_state= 20
# 0.9928367321552828
# random_state= 21
# 0.9930010178396953
# random_state= 22
# 0.9929327202949877
# random_state= 23
# 0.9937374411804066
# random_state= 24
# ...
