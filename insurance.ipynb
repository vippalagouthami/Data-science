# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dfin=pd.read_csv(r"C:\Users\Legion\OneDrive\Desktop\data\insurance.csv")

# %%
dfin
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.boxplot(dfin)
# Out:
# <Axes: >

# %%
dfin.isna().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.boxplot(dfin["bmi"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2423ad02320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2423ad02860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2423ad02080>],
#  'medians': [<matplotlib.lines.Line2D at 0x2423ad02c80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2423ad02f20>],
#  'means': []}

# %%
plt.boxplot(dfin["charges"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2423de74b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2423de75060>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2423de74880>],
#  'medians': [<matplotlib.lines.Line2D at 0x2423de755a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2423de75840>],
#  'means': []}

# %%
plt.hist(dfin["bmi"],bins=10,ec="y")
# Out:
# (array([ 30., 127., 234., 319., 288., 195.,  96.,  32.,  14.,   3.]),
#  array([15.96 , 19.677, 23.394, 27.111, 30.828, 34.545, 38.262, 41.979,
#         45.696, 49.413, 53.13 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dfin["charges"],bins=10,ec="y")
# Out:
# (array([536., 398., 129.,  86.,  35.,  59.,  57.,  32.,   2.,   4.]),
#  array([ 1121.8739  ,  7386.729311, 13651.584722, 19916.440133,
#         26181.295544, 32446.150955, 38711.006366, 44975.861777,
#         51240.717188, 57505.572599, 63770.42801 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(dfin["bmi"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20520\3391332890.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfin["bmi"])

# %%
sns.distplot(dfin["charges"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20520\616903433.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfin["charges"])

# %%
sns.displot(dfin["bmi"])

# %%
sns.displot(dfin["charges"])

# %%
dfin["bmi"].skew()
# Out:
# 0.2840471105987448

# %%
dfin["charges"].skew()
# Out:
# 1.5158796580240388

# %%
m=dfin["bmi"].mean()

# %%
m
# Out:
# 30.66339686098655

# %%
s=dfin["bmi"].std()

# %%
s
# Out:
# 6.098186911679017

# %%
lower=m-(3*s)

# %%
upper=m+(3*s)

# %%
lower
# Out:
# 12.368836125949496

# %%
upper
# Out:
# 48.957957596023604

# %%
dfin[dfin["bmi"]<lower]
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
dfin[dfin["bmi"]>upper]
# Out:
#       age gender    bmi  children smoker     region     charges
# 116    58   male  49.06         0     no  southeast  11381.3254
# 847    23   male  50.38         1     no  southeast   2438.0552
# 1047   22   male  52.58         1    yes  southeast  44501.3982
# 1317   18   male  53.13         0     no  southeast   1163.4627

# %%
dfin[(dfin["bmi"]<lower)|(dfin["bmi"]>upper)]
# Out:
#       age gender    bmi  children smoker     region     charges
# 116    58   male  49.06         0     no  southeast  11381.3254
# 847    23   male  50.38         1     no  southeast   2438.0552
# 1047   22   male  52.58         1    yes  southeast  44501.3982
# 1317   18   male  53.13         0     no  southeast   1163.4627

# %%
dfin["bmi"].map(lambda x:lower if x<lower else upper if x>upper else x)
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
dfin["bmi"]=dfin["bmi"].map(lambda x:lower if x<lower else upper if x>upper else x)

# %%
dfin
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfin[(dfin["bmi"]<lower)|(dfin["bmi"]>upper)]
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
dfin
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# IQR

# %%
#q1=dfin["charges"].quantile(0.25)

# %%
#q1

# %%
#q3=dfin["charges"].quantile(0.75)

# %%
#q3

# %%
#IQR=q3-q1

# %%
#IQR

# %%
#l1=q1-(1.5*IQR)

# %%
#l1

# %%
#u1=q3+(1.5*IQR)

# %%
#u1

# %%
#dfin[dfin["charges"]<l1]

# %%
#dfin[dfin["charges"]>u1]

# %%
#dfin[(dfin["charges"]<l1)|(dfin["charges"]>u1)]

# %%
#dfin["charges"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x )

# %%
#dfin["charges"]=dfin["charges"].map(lambda x:m if x<l1 else m if x>u1 else x )

# %%
#dfin

# %%
#dfin[(dfin["charges"]<l1)|(dfin["charges"]>u1)]

# %%
#dfin["charges"].isna().sum()

# %%
#dfin["charges"].mean()

# %%
#np.round(dfin["charges"].mean())

# %%
#dfin["charges"].fillna(np.round(dfin["charges"].mean()))

# %%
#dfin["charges"]=dfin["charges"].fillna(np.round(dfin["charges"].mean()))

# %%
#dfin["region"].unique()

# %%
dfin
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
 pd.get_dummies(dfin)
# Out:
#       age     bmi  children      charges  gender_female  gender_male  \
# 0      19  27.900         0  16884.92400              1            0
# 1      18  33.770         1   1725.55230              0            1
# 2      28  33.000         3   4449.46200              0            1
# 3      33  22.705         0  21984.47061              0            1
# 4      32  28.880         0   3866.85520              0            1
# ...   ...     ...       ...          ...            ...          ...
# 1333   50  30.970         3  10600.54830              0            1
# 1334   18  31.920         0   2205.98080              1            0
# 1335   18  36.850         0   1629.83350              1            0
# 1336   21  25.800         0   2007.94500              1            0
# 1337   61  29.070         0  29141.36030              1            0
#
#       smoker_no  smoker_yes  region_northeast  region_northwest  \
# 0             0           1                 0                 0
# ...

# %%
 pd.get_dummies(dfin,drop_first=True)
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# ...   ...     ...       ...          ...          ...         ...
# 1333   50  30.970         3  10600.54830            1           0
# 1334   18  31.920         0   2205.98080            0           0
# 1335   18  36.850         0   1629.83350            0           0
# 1336   21  25.800         0   2007.94500            0           0
# 1337   61  29.070         0  29141.36030            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# ...

# %%
dfin= pd.get_dummies(dfin,drop_first=True)

# %%
dfin
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# ...   ...     ...       ...          ...          ...         ...
# 1333   50  30.970         3  10600.54830            1           0
# 1334   18  31.920         0   2205.98080            0           0
# 1335   18  36.850         0   1629.83350            0           0
# 1336   21  25.800         0   2007.94500            0           0
# 1337   61  29.070         0  29141.36030            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# ...

# %%
X=dfin.drop("charges",axis=1)

# %%
X
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 0      19  27.900         0            0           1                 0
# 1      18  33.770         1            1           0                 0
# 2      28  33.000         3            1           0                 0
# 3      33  22.705         0            1           0                 1
# 4      32  28.880         0            1           0                 1
# ...   ...     ...       ...          ...         ...               ...
# 1333   50  30.970         3            1           0                 1
# 1334   18  31.920         0            0           0                 0
# 1335   18  36.850         0            0           0                 0
# 1336   21  25.800         0            0           0                 0
# 1337   61  29.070         0            0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# ...

# %%
y=dfin["charges"]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
plt.scatter(dfin["bmi"],dfin["charges"])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly3= PolynomialFeatures(degree=3)

# %%
poly3.fit(X,y)
# Out:
# PolynomialFeatures(degree=3)

# %%
poly3.transform(X)
# Out:
# array([[ 1.  , 19.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [ 1.  , 18.  , 33.77, ...,  0.  ,  0.  ,  0.  ],
#        [ 1.  , 28.  , 33.  , ...,  0.  ,  0.  ,  0.  ],
#        ...,
#        [ 1.  , 18.  , 36.85, ...,  0.  ,  0.  ,  0.  ],
#        [ 1.  , 21.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [ 1.  , 61.  , 29.07, ...,  0.  ,  0.  ,  0.  ]])

# %% [markdown]
# splitting of data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((1338, 8), (1070, 8), (268, 8))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((1338,), (1070,), (268,))

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
dtree1=DecisionTreeRegressor()
svm1=SVR()
rfr1=RandomForestRegressor()
ada1=AdaBoostRegressor()
grad1=GradientBoostingRegressor()
xgb1=XGBRegressor()
lreg1=LinearRegression()
knn1=KNeighborsRegressor()
clist=[dtree1,svm1,rfr1,ada1,grad1,xgb1,lreg1,knn1]

# %%
clist
# Out:
# [DecisionTreeRegressor(),
#  SVR(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor(),
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  LinearRegression(),
#  KNeighborsRegressor()]

# %%
import time
for i in clist:
    print(i,end="==>")
    i.fit(X_train,y_train)
    m=i.score(X_train,y_train)
    print(m)
    time.sleep(1)
# Out:
# DecisionTreeRegressor()==>0.998267338785144
# SVR()==>-0.10391321564623479
# RandomForestRegressor()==>0.9762774800730393
# AdaBoostRegressor()==>0.8299827558708968
# GradientBoostingRegressor()==>0.8993995277379632
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
# ...

# %%
for m in clist:
        print(m,end="==>")  
        rlist=[]
        for i in range (0,51):
            print("random_state=",i)
            X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
            m.fit(X_train,y_train)
            s=m.score(X_test,y_test)
            print(s)
            rlist.append(s) 
print("--------------------------------------------------------------------------")
print("Max =",max(rlist)) 
rlist.index(max(rlist))
print("Max_index=",rlist.index(max(rlist)))
print("---------------------------------------------------------------------------")
# Out:
# DecisionTreeRegressor()==>random_state= 0
# 0.7004274660246266
# random_state= 1
# 0.7628003531848402
# random_state= 2
# 0.6700963227578581
# random_state= 3
# 0.7542912280015677
# random_state= 4
# 0.6930427454721775
# random_state= 5
# 0.7245719498598895
# random_state= 6
# 0.7452374736128651
# random_state= 7
# 0.7242449038987908
# random_state= 8
# 0.7006625531442674
# random_state= 9
# 0.7210888960796311
# random_state= 10
# 0.6345405669595949
# random_state= 11
# 0.7488104366638184
# random_state= 12
# 0.7050965925045258
# random_state= 13
# 0.8251560527131561
# random_state= 14
# 0.7479126412350992
# random_state= 15
# 0.6882968506425386
# random_state= 16
# 0.7181479946679472
# random_state= 17
# 0.6866367977639465
# random_state= 18
# 0.7536384521169863
# random_state= 19
# 0.7601460596618282
# random_state= 20
# 0.7807147623572134
# random_state= 21
# 0.653233672940426
# random_state= 22
# 0.612781041608925
# random_state= 23
# 0.6651591477848294
# random_state= 24
# ...
