# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfgold=pd.read_csv(r"C:\Users\Legion\OneDrive\Desktop\data\gld_price_data.csv")

# %%
dfgold
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
dfgold.isna().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
sns.boxplot(dfgold)
# Out:
# <Axes: >

# %%
dfgold.columns
# Out:
# Index(['Date', 'SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
plt.boxplot(dfgold["SPX"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f4c49a590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21f4c49aad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21f4c49a2f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f4c49b010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f4c49b2b0>],
#  'means': []}

# %%
sns.boxplot(dfgold["GLD"])
# Out:
# <Axes: >

# %%
sns.boxplot(dfgold["USO"])
# Out:
# <Axes: >

# %%
sns.boxplot(dfgold["SLV"])
# Out:
# <Axes: >

# %%
sns.distplot(dfgold["SPX"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20168\3661409026.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfgold["SPX"])
# <Axes: xlabel='SPX', ylabel='Density'>

# %%
sns.distplot(dfgold["GLD"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20168\2510908600.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfgold["GLD"])
# <Axes: xlabel='GLD', ylabel='Density'>

# %%
sns.distplot(dfgold["USO"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20168\4085281249.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfgold["USO"])
# <Axes: xlabel='USO', ylabel='Density'>

# %%
sns.distplot(dfgold["SLV"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_20168\1920077167.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfgold["SLV"])
# <Axes: xlabel='SLV', ylabel='Density'>

# %%
dfgold["SPX"].skew()
# Out:
# 0.3003618142394941

# %%
dfgold["GLD"].skew()
# Out:
# 0.3341383472692508

# %%
dfgold["USO"].skew()
# Out:
# 1.6993309916429733

# %%
dfgold["SLV"].skew()
# Out:
# 1.1536409144141129

# %% [markdown]
# error detection for uso

# %%
q1=dfgold["USO"].quantile(0.25)

# %%
q1
# Out:
# 14.38

# %%
q3=dfgold["USO"].quantile(0.75)

# %%
q3
# Out:
# 37.8275015

# %%
IQR=q3-q1

# %%
l=q1-(1.5*IQR)

# %%
l
# Out:
# -20.791252249999992

# %%
u=q3+(1.5*IQR)

# %%
u
# Out:
# 72.99875374999999

# %%
dfgold[dfgold["USO"]<l]
# Out:
# Empty DataFrame
# Columns: [Date, SPX, GLD, USO, SLV, EUR/USD]
# Index: []

# %%
dfgold[dfgold["USO"]>u]
# Out:
#           Date          SPX        GLD        USO     SLV   EUR/USD
# 0     1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1     1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2     1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3     1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4     1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099
# ..         ...          ...        ...        ...     ...       ...
# 146  9/25/2008  1209.180054  86.449997  86.690002  13.030  1.459897
# 147  9/29/2008  1106.420044  89.570000  77.089996  12.950  1.409642
# 148  9/30/2008  1166.359985  85.070000  82.010002  11.850  1.401620
# 149  10/1/2008  1161.060059  85.970001  79.589996  12.330  1.380796
# 150  10/2/2008  1114.280029  82.330002  75.820000  10.800  1.378493
#
# [134 rows x 6 columns]

# %%
dfgold[(dfgold["USO"]<l)|(dfgold["USO"]>u)]
# Out:
#           Date          SPX        GLD        USO     SLV   EUR/USD
# 0     1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1     1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2     1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3     1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4     1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099
# ..         ...          ...        ...        ...     ...       ...
# 146  9/25/2008  1209.180054  86.449997  86.690002  13.030  1.459897
# 147  9/29/2008  1106.420044  89.570000  77.089996  12.950  1.409642
# 148  9/30/2008  1166.359985  85.070000  82.010002  11.850  1.401620
# 149  10/1/2008  1161.060059  85.970001  79.589996  12.330  1.380796
# 150  10/2/2008  1114.280029  82.330002  75.820000  10.800  1.378493
#
# [134 rows x 6 columns]

# %%
dfgold["USO"].map(lambda x:l if x<l else u if x>u else x)
# Out:
# 0       72.998754
# 1       72.998754
# 2       72.998754
# 3       72.998754
# 4       72.998754
#           ...
# 2285    14.060000
# 2286    14.370000
# 2287    14.410000
# 2288    14.380000
# 2289    14.405800
# Name: USO, Length: 2290, dtype: float64

# %%
dfgold["USO"]=dfgold["USO"].map(lambda x:l if x<l else u if x>u else x)

# %%
dfgold
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  72.998754  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  72.998754  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  72.998754  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  72.998754  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  72.998754  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %% [markdown]
# Error for SLV

# %%
q11=dfgold["SLV"].quantile(0.25)

# %%
q11
# Out:
# 15.57

# %%
q33=dfgold["SLV"].quantile(0.75)

# %%
IQR=q33-q11

# %%
IQR
# Out:
# 7.312499500000001

# %%
l1=q11-(1.5*IQR)

# %%
l1
# Out:
# 4.601250749999998

# %%
u1=q33+(1.5*IQR)

# %%
u1
# Out:
# 33.85124875

# %%
dfgold[dfgold["SLV"]<l1]
# Out:
# Empty DataFrame
# Columns: [Date, SPX, GLD, USO, SLV, EUR/USD]
# Index: []

# %%
dfgold[dfgold["SLV"]>u1]
# Out:
#            Date          SPX         GLD        USO        SLV   EUR/USD
# 694    3/1/2011  1306.329956  140.029999  40.480000  33.869999  1.382151
# 697    3/4/2011  1321.150024  139.350006  42.330002  34.689999  1.395888
# 698    3/7/2011  1310.130005  139.720001  42.369999  35.230000  1.399071
# 699    3/8/2011  1321.819946  139.360001  42.310001  35.180000  1.396394
# 700    3/9/2011  1320.020020  139.410004  42.049999  35.270000  1.389796
# ...         ...          ...         ...        ...        ...       ...
# 913   2/24/2012  1365.739990  172.229996  42.009998  34.369999  1.337363
# 914   2/27/2012  1367.589966  171.699997  41.180000  34.360001  1.346711
# 915   2/28/2012  1372.180054  173.490005  40.790001  35.830002  1.340662
# 917    3/1/2012  1374.089966  166.610001  41.750000  34.439999  1.332090
# 1042  10/4/2012  1461.400024  173.610001  33.939999  33.930000  1.301744
#
# [117 rows x 6 columns]

# %%
dfgold[(dfgold["SLV"]<l1)|(dfgold["SLV"]>u1)]
# Out:
#            Date          SPX         GLD        USO        SLV   EUR/USD
# 694    3/1/2011  1306.329956  140.029999  40.480000  33.869999  1.382151
# 697    3/4/2011  1321.150024  139.350006  42.330002  34.689999  1.395888
# 698    3/7/2011  1310.130005  139.720001  42.369999  35.230000  1.399071
# 699    3/8/2011  1321.819946  139.360001  42.310001  35.180000  1.396394
# 700    3/9/2011  1320.020020  139.410004  42.049999  35.270000  1.389796
# ...         ...          ...         ...        ...        ...       ...
# 913   2/24/2012  1365.739990  172.229996  42.009998  34.369999  1.337363
# 914   2/27/2012  1367.589966  171.699997  41.180000  34.360001  1.346711
# 915   2/28/2012  1372.180054  173.490005  40.790001  35.830002  1.340662
# 917    3/1/2012  1374.089966  166.610001  41.750000  34.439999  1.332090
# 1042  10/4/2012  1461.400024  173.610001  33.939999  33.930000  1.301744
#
# [117 rows x 6 columns]

# %%
dfgold["SLV"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)
# Out:
# 0       15.1800
# 1       15.2850
# 2       15.1670
# 3       15.0530
# 4       15.5900
#          ...
# 2285    15.5100
# 2286    15.5300
# 2287    15.7400
# 2288    15.5600
# 2289    15.4542
# Name: SLV, Length: 2290, dtype: float64

# %%
dfgold["SLV"]=dfgold["SLV"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)

# %%
dfgold
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  72.998754  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  72.998754  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  72.998754  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  72.998754  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  72.998754  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
dfgold.drop("Date",axis=1,inplace=True)

# %%
X=dfgold.drop("GLD",axis=1)

# %%
X
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  72.998754  15.1800  1.471692
# 1     1447.160034  72.998754  15.2850  1.474491
# 2     1411.630005  72.998754  15.1670  1.475492
# 3     1416.180054  72.998754  15.0530  1.468299
# 4     1390.189941  72.998754  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
y=dfgold["GLD"]

# %%
y
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((2290, 4), (1832, 4), (458, 4))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((2290,), (1832,), (458,))

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
dtree1=DecisionTreeRegressor()
svm1=SVR()
rfr1=RandomForestRegressor()
ada1=AdaBoostRegressor()
grad1=GradientBoostingRegressor()
xgb1=XGBRegressor()
lreg1=LinearRegression()
knn1=KNeighborsRegressor()
clist=[dtree1,svm1,rfr1,ada1,grad1,xgb1,lreg1,knn1]

# %%
clist
# Out:
# [DecisionTreeRegressor(),
#  SVR(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor(),
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  LinearRegression(),
#  KNeighborsRegressor()]

# %%
import time
for i in clist:
    print(i,end="==>")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    print(m)
    time.sleep(1)
# Out:
# DecisionTreeRegressor()==>0.9829313625652291
# SVR()==>0.11678834464265431
# RandomForestRegressor()==>0.9905685803441873
# AdaBoostRegressor()==>0.9450335258969548
# GradientBoostingRegressor()==>0.9779811994223498
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
# ...

# %%
for m in clist:
        print(m,end="==>")  
        rlist=[]
        for i in range (0,51):
            print("random_state=",i)
            X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
            m.fit(X_train,y_train)
            s=m.score(X_test,y_test)
            print(s)
            rlist.append(s) 
print("--------------------------------------------------------------------------")
print("Max =",max(rlist)) 
rlist.index(max(rlist))
print("Max_index=",rlist.index(max(rlist)))
print("---------------------------------------------------------------------------")
# Out:
# DecisionTreeRegressor()==>random_state= 0
# 0.9858243020009554
# random_state= 1
# 0.9731787568535796
# random_state= 2
# 0.9868896738996884
# random_state= 3
# 0.9765158536408634
# random_state= 4
# 0.9794086773721706
# random_state= 5
# 0.9827812299428186
# random_state= 6
# 0.9803898290234824
# random_state= 7
# 0.9721505223584918
# random_state= 8
# 0.9779118332732971
# random_state= 9
# 0.9737550367807782
# random_state= 10
# 0.9823808754114267
# random_state= 11
# 0.9838571367668643
# random_state= 12
# 0.9716799789320318
# random_state= 13
# 0.9748267081055325
# random_state= 14
# 0.9787305039533627
# random_state= 15
# 0.9813308915174159
# random_state= 16
# 0.981773902532571
# random_state= 17
# 0.9828504201945718
# random_state= 18
# 0.9799422447160759
# random_state= 19
# 0.9808653206323055
# random_state= 20
# 0.9663185602346093
# random_state= 21
# 0.9793122036622353
# random_state= 22
# 0.9870493675976789
# random_state= 23
# 0.9845770898300634
# random_state= 24
# ...
