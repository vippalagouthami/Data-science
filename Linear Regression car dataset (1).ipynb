# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfcar=pd.read_csv("C:\\Users\\Legion\\OneDrive\\Desktop\\data\\linear regression\\Car Dataset-20230627T013925Z-001\\Car Dataset\\car data.csv")

# %%
dfcar
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
dfcar.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
dfcar.columns=['CarName', 'Year', 'SellingPrice', 'PresentPrice', 'Kms',
       'FuelType', 'SellerType', 'Transmission', 'Owner']

# %%
dfcar
# Out:
#      CarName  Year  SellingPrice  PresentPrice    Kms FuelType SellerType  \
# 0       ritz  2014          3.35          5.59  27000   Petrol     Dealer
# 1        sx4  2013          4.75          9.54  43000   Diesel     Dealer
# 2       ciaz  2017          7.25          9.85   6900   Petrol     Dealer
# 3    wagon r  2011          2.85          4.15   5200   Petrol     Dealer
# 4      swift  2014          4.60          6.87  42450   Diesel     Dealer
# ..       ...   ...           ...           ...    ...      ...        ...
# 296     city  2016          9.50         11.60  33988   Diesel     Dealer
# 297     brio  2015          4.00          5.90  60000   Petrol     Dealer
# 298     city  2009          3.35         11.00  87934   Petrol     Dealer
# 299     city  2017         11.50         12.50   9000   Diesel     Dealer
# 300     brio  2016          5.30          5.90   5464   Petrol     Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
dfcar.isna().sum()
# Out:
# CarName         0
# Year            0
# SellingPrice    0
# PresentPrice    0
# Kms             0
# FuelType        0
# SellerType      0
# Transmission    0
# Owner           0
# dtype: int64

# %%
dfcar["FuelType"].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
dfcar["SellerType"].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
dfcar["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
sns.boxplot(dfcar)
# Out:
# <Axes: >

# %%
sns.boxplot(dfcar["Year"])
# Out:
# <Axes: >

# %%
plt.boxplot(dfcar["SellingPrice"])
plt.show()

# %%
plt.boxplot(dfcar["PresentPrice"])
plt.show()

# %%
plt.boxplot(dfcar["Kms"])
plt.show()

# %%
dfcar.describe()
# Out:
#               Year  SellingPrice  PresentPrice            Kms       Owner
# count   301.000000    301.000000    301.000000     301.000000  301.000000
# mean   2013.627907      4.661296      7.628472   36947.205980    0.043189
# std       2.891554      5.082812      8.644115   38886.883882    0.247915
# min    2003.000000      0.100000      0.320000     500.000000    0.000000
# 25%    2012.000000      0.900000      1.200000   15000.000000    0.000000
# 50%    2014.000000      3.600000      6.400000   32000.000000    0.000000
# 75%    2016.000000      6.000000      9.900000   48767.000000    0.000000
# max    2018.000000     35.000000     92.600000  500000.000000    3.000000

# %%
plt.hist(dfcar["SellingPrice"],bins=10,ec="yellow")
# Out:
# (array([150.,  91.,  34.,   9.,   6.,   5.,   4.,   0.,   0.,   2.]),
#  array([ 0.1 ,  3.59,  7.08, 10.57, 14.06, 17.55, 21.04, 24.53, 28.02,
#         31.51, 35.  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(dfcar["SellingPrice"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\320846837.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["SellingPrice"])

# %%
sns.distplot(dfcar["PresentPrice"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\1388298352.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["PresentPrice"])

# %%
sns.distplot(dfcar["Kms"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\1524347505.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["Kms"])

# %%
sns.distplot(dfcar["Year"])
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\175276232.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["Year"])

# %%
dfcar["PresentPrice"].skew()
# Out:
# 4.083150156592918

# %%
dfcar["SellingPrice"].skew()
# Out:
# 2.493422417797524

# %%
dfcar["Year"].skew()
# Out:
# -1.2461891109538386

# %%
dfcar["Kms"].skew()
# Out:
# 6.436012679752193

# %%
q1=dfcar["SellingPrice"].quantile(0.25)

# %%
q1
# Out:
# 0.9

# %%
q3=dfcar["SellingPrice"].quantile(0.75)

# %%
q3
# Out:
# 6.0

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 5.1

# %%
lower=q1-1.5*IQR

# %%
lower
# Out:
# -6.749999999999999

# %%
upper=q3+1.5*IQR

# %%
upper
# Out:
# 13.649999999999999

# %%
dfcar[dfcar["SellingPrice"]<lower]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
dfcar[dfcar["SellingPrice"]>upper]
# Out:
#           CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 50       fortuner  2012         14.90         30.61  104707   Diesel
# 51       fortuner  2015         23.00         30.61   40000   Diesel
# 52         innova  2017         18.00         19.77   15000   Diesel
# 53       fortuner  2013         16.00         30.61  135000   Diesel
# 59       fortuner  2014         19.99         35.96   41000   Diesel
# 62       fortuner  2014         18.75         35.96   78000   Diesel
# 63       fortuner  2015         23.50         35.96   47000   Diesel
# 64       fortuner  2017         33.00         36.23    6000   Diesel
# 66         innova  2017         19.75         23.15   11000   Petrol
# 69  corolla altis  2016         14.25         20.91   12000   Petrol
# 79       fortuner  2012         14.50         30.61   89000   Diesel
# 80  corolla altis  2016         14.73         14.89   23000   Diesel
# 82         innova  2017         23.00         25.39   15000   Diesel
# ...

# %%
dfcar[(dfcar["SellingPrice"]<lower)|(dfcar["SellingPrice"]>upper)]
# Out:
#           CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 50       fortuner  2012         14.90         30.61  104707   Diesel
# 51       fortuner  2015         23.00         30.61   40000   Diesel
# 52         innova  2017         18.00         19.77   15000   Diesel
# 53       fortuner  2013         16.00         30.61  135000   Diesel
# 59       fortuner  2014         19.99         35.96   41000   Diesel
# 62       fortuner  2014         18.75         35.96   78000   Diesel
# 63       fortuner  2015         23.50         35.96   47000   Diesel
# 64       fortuner  2017         33.00         36.23    6000   Diesel
# 66         innova  2017         19.75         23.15   11000   Petrol
# 69  corolla altis  2016         14.25         20.91   12000   Petrol
# 79       fortuner  2012         14.50         30.61   89000   Diesel
# 80  corolla altis  2016         14.73         14.89   23000   Diesel
# 82         innova  2017         23.00         25.39   15000   Diesel
# ...

# %%
dfcar["SellingPrice"].map(lambda x: lower if x<lower else upper if x>upper else x )
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: SellingPrice, Length: 301, dtype: float64

# %%
dfcar["SellingPrice"]=dfcar["SellingPrice"].map(lambda x: lower if x<lower else upper if x>upper else x )

# %%
dfcar
# Out:
#      CarName  Year  SellingPrice  PresentPrice    Kms FuelType SellerType  \
# 0       ritz  2014          3.35          5.59  27000   Petrol     Dealer
# 1        sx4  2013          4.75          9.54  43000   Diesel     Dealer
# 2       ciaz  2017          7.25          9.85   6900   Petrol     Dealer
# 3    wagon r  2011          2.85          4.15   5200   Petrol     Dealer
# 4      swift  2014          4.60          6.87  42450   Diesel     Dealer
# ..       ...   ...           ...           ...    ...      ...        ...
# 296     city  2016          9.50         11.60  33988   Diesel     Dealer
# 297     brio  2015          4.00          5.90  60000   Petrol     Dealer
# 298     city  2009          3.35         11.00  87934   Petrol     Dealer
# 299     city  2017         11.50         12.50   9000   Diesel     Dealer
# 300     brio  2016          5.30          5.90   5464   Petrol     Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
dfcar[(dfcar["SellingPrice"]<lower)|(dfcar["SellingPrice"]>upper)]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
plt.hist(dfcar["PresentPrice"])
# Out:
# (array([223.,  58.,  10.,   9.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 0.32 ,  9.548, 18.776, 28.004, 37.232, 46.46 , 55.688, 64.916,
#         74.144, 83.372, 92.6  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(dfcar["PresentPrice"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\1506394288.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["PresentPrice"])
# <Axes: xlabel='PresentPrice', ylabel='Density'>

# %%
q12=dfcar["PresentPrice"].quantile(0.25)

# %%
q12
# Out:
# 1.2

# %%
q32=dfcar["PresentPrice"].quantile(0.75)

# %%
q32
# Out:
# 9.9

# %%
IQR=q32-q12

# %%
IQR
# Out:
# 8.700000000000001

# %%
l1=q12-1.5*IQR

# %%
l1
# Out:
# -11.850000000000001

# %%
u1=q32+1.5*IQR

# %%
u1
# Out:
# 22.950000000000003

# %%
dfcar[dfcar["PresentPrice"]<l1]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
dfcar[dfcar["PresentPrice"]>u1]
# Out:
#          CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 50      fortuner  2012         13.65         30.61  104707   Diesel
# 51      fortuner  2015         13.65         30.61   40000   Diesel
# 53      fortuner  2013         13.65         30.61  135000   Diesel
# 59      fortuner  2014         13.65         35.96   41000   Diesel
# 62      fortuner  2014         13.65         35.96   78000   Diesel
# 63      fortuner  2015         13.65         35.96   47000   Diesel
# 64      fortuner  2017         13.65         36.23    6000   Diesel
# 66        innova  2017         13.65         23.15   11000   Petrol
# 79      fortuner  2012         13.65         30.61   89000   Diesel
# 82        innova  2017         13.65         25.39   15000   Diesel
# 85         camry  2006          2.50         23.73  142000   Petrol
# 86  land cruiser  2010         13.65         92.60   78000   Diesel
# 93      fortuner  2015         13.65         30.61   40000   Diesel
# ...

# %%
dfcar[(dfcar["PresentPrice"]<l1)|(dfcar["PresentPrice"]>u1)]
# Out:
#          CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 50      fortuner  2012         13.65         30.61  104707   Diesel
# 51      fortuner  2015         13.65         30.61   40000   Diesel
# 53      fortuner  2013         13.65         30.61  135000   Diesel
# 59      fortuner  2014         13.65         35.96   41000   Diesel
# 62      fortuner  2014         13.65         35.96   78000   Diesel
# 63      fortuner  2015         13.65         35.96   47000   Diesel
# 64      fortuner  2017         13.65         36.23    6000   Diesel
# 66        innova  2017         13.65         23.15   11000   Petrol
# 79      fortuner  2012         13.65         30.61   89000   Diesel
# 82        innova  2017         13.65         25.39   15000   Diesel
# 85         camry  2006          2.50         23.73  142000   Petrol
# 86  land cruiser  2010         13.65         92.60   78000   Diesel
# 93      fortuner  2015         13.65         30.61   40000   Diesel
# ...

# %%
dfcar["PresentPrice"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)
# Out:
# 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: PresentPrice, Length: 301, dtype: float64

# %%
dfcar["PresentPrice"]=dfcar["PresentPrice"].map(lambda x:l1 if x<l1 else u1 if x>u1 else x)

# %%
dfcar["PresentPrice"]
# Out:
# 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: PresentPrice, Length: 301, dtype: float64

# %%
dfcar[(dfcar["PresentPrice"]<l1)|(dfcar["PresentPrice"]>u1)]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
dfcar
# Out:
#      CarName  Year  SellingPrice  PresentPrice    Kms FuelType SellerType  \
# 0       ritz  2014          3.35          5.59  27000   Petrol     Dealer
# 1        sx4  2013          4.75          9.54  43000   Diesel     Dealer
# 2       ciaz  2017          7.25          9.85   6900   Petrol     Dealer
# 3    wagon r  2011          2.85          4.15   5200   Petrol     Dealer
# 4      swift  2014          4.60          6.87  42450   Diesel     Dealer
# ..       ...   ...           ...           ...    ...      ...        ...
# 296     city  2016          9.50         11.60  33988   Diesel     Dealer
# 297     brio  2015          4.00          5.90  60000   Petrol     Dealer
# 298     city  2009          3.35         11.00  87934   Petrol     Dealer
# 299     city  2017         11.50         12.50   9000   Diesel     Dealer
# 300     brio  2016          5.30          5.90   5464   Petrol     Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
plt.boxplot(dfcar["Kms"])
plt.show()

# %%
sns.distplot(dfcar["Kms"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\4160518887.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["Kms"])
# <Axes: xlabel='Kms', ylabel='Density'>

# %%
dfcar["Kms"].skew()
# Out:
# 6.436012679752193

# %%
q13=dfcar["Kms"].quantile(0.25)

# %%
q13
# Out:
# 15000.0

# %%
q33=dfcar["Kms"].quantile(0.75)

# %%
q33
# Out:
# 48767.0

# %%
IQR=q33-q13

# %%
IQR
# Out:
# 33767.0

# %%
l2=q13-1.5*IQR

# %%
l2
# Out:
# -35650.5

# %%
u2=q33+1.5*IQR

# %%
u2
# Out:
# 99417.5

# %%
dfcar[dfcar["Kms"]<l2]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
dfcar[dfcar["Kms"]>u2]
# Out:
#            CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 37             800  2003          0.35          2.28  127000   Petrol
# 50        fortuner  2012         13.65         22.95  104707   Diesel
# 53        fortuner  2013         13.65         22.95  135000   Diesel
# 77         corolla  2004          1.50         12.35  135154   Petrol
# 84          innova  2005          3.49         13.46  197176   Diesel
# 85           camry  2006          2.50         22.95  142000   Petrol
# 179  Honda Karizma  2010          0.31          1.05  213000   Petrol
# 196      Activa 3g  2008          0.17          0.52  500000   Petrol
#
#      SellerType Transmission  Owner
# 37   Individual       Manual      0
# 50       Dealer    Automatic      0
# 53   Individual    Automatic      0
# 77       Dealer    Automatic      0
# 84       Dealer       Manual      0
# 85   Individual    Automatic      3
# 179  Individual       Manual      0
# 196  Individual    Automatic      0

# %%
dfcar[(dfcar["Kms"]<l2)|(dfcar["Kms"]>u2)]
# Out:
#            CarName  Year  SellingPrice  PresentPrice     Kms FuelType  \
# 37             800  2003          0.35          2.28  127000   Petrol
# 50        fortuner  2012         13.65         22.95  104707   Diesel
# 53        fortuner  2013         13.65         22.95  135000   Diesel
# 77         corolla  2004          1.50         12.35  135154   Petrol
# 84          innova  2005          3.49         13.46  197176   Diesel
# 85           camry  2006          2.50         22.95  142000   Petrol
# 179  Honda Karizma  2010          0.31          1.05  213000   Petrol
# 196      Activa 3g  2008          0.17          0.52  500000   Petrol
#
#      SellerType Transmission  Owner
# 37   Individual       Manual      0
# 50       Dealer    Automatic      0
# 53   Individual    Automatic      0
# 77       Dealer    Automatic      0
# 84       Dealer       Manual      0
# 85   Individual    Automatic      3
# 179  Individual       Manual      0
# 196  Individual    Automatic      0

# %%
dfcar["Kms"].map(lambda x:l2 if x<l2 else u2 if x>u2 else x)
# Out:
# 0      27000.0
# 1      43000.0
# 2       6900.0
# 3       5200.0
# 4      42450.0
#         ...
# 296    33988.0
# 297    60000.0
# 298    87934.0
# 299     9000.0
# 300     5464.0
# Name: Kms, Length: 301, dtype: float64

# %%
dfcar["Kms"]=dfcar["Kms"].map(lambda x:l2 if x<l2 else u2 if x>u2 else x)

# %%
dfcar
# Out:
#      CarName  Year  SellingPrice  PresentPrice      Kms FuelType SellerType  \
# 0       ritz  2014          3.35          5.59  27000.0   Petrol     Dealer
# 1        sx4  2013          4.75          9.54  43000.0   Diesel     Dealer
# 2       ciaz  2017          7.25          9.85   6900.0   Petrol     Dealer
# 3    wagon r  2011          2.85          4.15   5200.0   Petrol     Dealer
# 4      swift  2014          4.60          6.87  42450.0   Diesel     Dealer
# ..       ...   ...           ...           ...      ...      ...        ...
# 296     city  2016          9.50         11.60  33988.0   Diesel     Dealer
# 297     brio  2015          4.00          5.90  60000.0   Petrol     Dealer
# 298     city  2009          3.35         11.00  87934.0   Petrol     Dealer
# 299     city  2017         11.50         12.50   9000.0   Diesel     Dealer
# 300     brio  2016          5.30          5.90   5464.0   Petrol     Dealer
#
#     Transmission  Owner
# 0         Manual      0
# ...

# %%
dfcar[(dfcar["Kms"]<l2)|(dfcar["Kms"]>u2)]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
plt.boxplot(dfcar["Year"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247dd757a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247dd757fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247dd7577f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x247dd798550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247db243f10>],
#  'means': []}

# %%
sns.distplot(dfcar["Year"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18700\4182946411.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfcar["Year"])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
dfcar["Year"].skew()
# Out:
# -1.2461891109538386

# %%
from scipy.stats.mstats import winsorize

# %%
m=dfcar["Year"].mean()

# %%
m
# Out:
# 2013.6279069767443

# %%
s=dfcar["Year"].std()

# %%
s
# Out:
# 2.891554127336682

# %%
l3=m-3*s

# %%
l3
# Out:
# 2004.9532445947343

# %%
u3=m+3*s

# %%
u3
# Out:
# 2022.3025693587542

# %%
dfcar[dfcar["Year"]<l3]
# Out:
#     CarName  Year  SellingPrice  PresentPrice      Kms FuelType  SellerType  \
# 37      800  2003          0.35          2.28  99417.5   Petrol  Individual
# 39      sx4  2003          2.25          7.98  62000.0   Petrol      Dealer
# 77  corolla  2004          1.50         12.35  99417.5   Petrol      Dealer
#
#    Transmission  Owner
# 37       Manual      0
# 39       Manual      0
# 77    Automatic      0

# %%
dfcar[dfcar["Year"]>u3]
# Out:
# Empty DataFrame
# Columns: [CarName, Year, SellingPrice, PresentPrice, Kms, FuelType, SellerType, Transmission, Owner]
# Index: []

# %%
dfcar[(dfcar["Year"]<l3)|(dfcar["Year"]>u3)]
# Out:
#     CarName  Year  SellingPrice  PresentPrice      Kms FuelType  SellerType  \
# 37      800  2003          0.35          2.28  99417.5   Petrol  Individual
# 39      sx4  2003          2.25          7.98  62000.0   Petrol      Dealer
# 77  corolla  2004          1.50         12.35  99417.5   Petrol      Dealer
#
#    Transmission  Owner
# 37       Manual      0
# 39       Manual      0
# 77    Automatic      0

# %%
dfcar["Year"].map(lambda x: l3 if x<l3 else u3 if x>u3 else x )
# Out:
# 0      2014.0
# 1      2013.0
# 2      2017.0
# 3      2011.0
# 4      2014.0
#         ...
# 296    2016.0
# 297    2015.0
# 298    2009.0
# 299    2017.0
# 300    2016.0
# Name: Year, Length: 301, dtype: float64

# %%
dfcar["Year"]=dfcar["Year"].map(lambda x: l3 if x<l3 else u3 if x>u3 else x )

# %%
dfcar
# Out:
#      CarName    Year  SellingPrice  PresentPrice      Kms FuelType SellerType  \
# 0       ritz  2014.0          3.35          5.59  27000.0   Petrol     Dealer
# 1        sx4  2013.0          4.75          9.54  43000.0   Diesel     Dealer
# 2       ciaz  2017.0          7.25          9.85   6900.0   Petrol     Dealer
# 3    wagon r  2011.0          2.85          4.15   5200.0   Petrol     Dealer
# 4      swift  2014.0          4.60          6.87  42450.0   Diesel     Dealer
# ..       ...     ...           ...           ...      ...      ...        ...
# 296     city  2016.0          9.50         11.60  33988.0   Diesel     Dealer
# 297     brio  2015.0          4.00          5.90  60000.0   Petrol     Dealer
# 298     city  2009.0          3.35         11.00  87934.0   Petrol     Dealer
# 299     city  2017.0         11.50         12.50   9000.0   Diesel     Dealer
# 300     brio  2016.0          5.30          5.90   5464.0   Petrol     Dealer
#
#     Transmission  Owner
# ...

# %%
cols=["CarName","FuelType","SellerType","Transmission"]

# %%
pd.get_dummies(dfcar[cols],drop_first=True)
# Out:
#      CarName_Activa 3g  CarName_Activa 4g  CarName_Bajaj  ct 100  \
# 0                    0                  0                      0
# 1                    0                  0                      0
# 2                    0                  0                      0
# 3                    0                  0                      0
# 4                    0                  0                      0
# ..                 ...                ...                    ...
# 296                  0                  0                      0
# 297                  0                  0                      0
# 298                  0                  0                      0
# 299                  0                  0                      0
# 300                  0                  0                      0
#
#      CarName_Bajaj Avenger 150  CarName_Bajaj Avenger 150 street  \
# 0                            0                                 0
# ...

# %%
dfno=pd.get_dummies(dfcar[cols],drop_first=True)

# %%
dfcar
# Out:
#      CarName    Year  SellingPrice  PresentPrice      Kms FuelType SellerType  \
# 0       ritz  2014.0          3.35          5.59  27000.0   Petrol     Dealer
# 1        sx4  2013.0          4.75          9.54  43000.0   Diesel     Dealer
# 2       ciaz  2017.0          7.25          9.85   6900.0   Petrol     Dealer
# 3    wagon r  2011.0          2.85          4.15   5200.0   Petrol     Dealer
# 4      swift  2014.0          4.60          6.87  42450.0   Diesel     Dealer
# ..       ...     ...           ...           ...      ...      ...        ...
# 296     city  2016.0          9.50         11.60  33988.0   Diesel     Dealer
# 297     brio  2015.0          4.00          5.90  60000.0   Petrol     Dealer
# 298     city  2009.0          3.35         11.00  87934.0   Petrol     Dealer
# 299     city  2017.0         11.50         12.50   9000.0   Diesel     Dealer
# 300     brio  2016.0          5.30          5.90   5464.0   Petrol     Dealer
#
#     Transmission  Owner
# ...

# %%
dfno
# Out:
#      CarName_Activa 3g  CarName_Activa 4g  CarName_Bajaj  ct 100  \
# 0                    0                  0                      0
# 1                    0                  0                      0
# 2                    0                  0                      0
# 3                    0                  0                      0
# 4                    0                  0                      0
# ..                 ...                ...                    ...
# 296                  0                  0                      0
# 297                  0                  0                      0
# 298                  0                  0                      0
# 299                  0                  0                      0
# 300                  0                  0                      0
#
#      CarName_Bajaj Avenger 150  CarName_Bajaj Avenger 150 street  \
# 0                            0                                 0
# ...

# %%
dfcar=pd.concat([dfcar,dfno],axis=1)

# %%
dfcar
# Out:
#      CarName    Year  SellingPrice  PresentPrice      Kms FuelType SellerType  \
# 0       ritz  2014.0          3.35          5.59  27000.0   Petrol     Dealer
# 1        sx4  2013.0          4.75          9.54  43000.0   Diesel     Dealer
# 2       ciaz  2017.0          7.25          9.85   6900.0   Petrol     Dealer
# 3    wagon r  2011.0          2.85          4.15   5200.0   Petrol     Dealer
# 4      swift  2014.0          4.60          6.87  42450.0   Diesel     Dealer
# ..       ...     ...           ...           ...      ...      ...        ...
# 296     city  2016.0          9.50         11.60  33988.0   Diesel     Dealer
# 297     brio  2015.0          4.00          5.90  60000.0   Petrol     Dealer
# 298     city  2009.0          3.35         11.00  87934.0   Petrol     Dealer
# 299     city  2017.0         11.50         12.50   9000.0   Diesel     Dealer
# 300     brio  2016.0          5.30          5.90   5464.0   Petrol     Dealer
#
# ...

# %%
dfcar.drop("Owner",axis=1,inplace=True)

# %%
dfcar
# Out:
#      CarName    Year  SellingPrice  PresentPrice      Kms FuelType SellerType  \
# 0       ritz  2014.0          3.35          5.59  27000.0   Petrol     Dealer
# 1        sx4  2013.0          4.75          9.54  43000.0   Diesel     Dealer
# 2       ciaz  2017.0          7.25          9.85   6900.0   Petrol     Dealer
# 3    wagon r  2011.0          2.85          4.15   5200.0   Petrol     Dealer
# 4      swift  2014.0          4.60          6.87  42450.0   Diesel     Dealer
# ..       ...     ...           ...           ...      ...      ...        ...
# 296     city  2016.0          9.50         11.60  33988.0   Diesel     Dealer
# 297     brio  2015.0          4.00          5.90  60000.0   Petrol     Dealer
# 298     city  2009.0          3.35         11.00  87934.0   Petrol     Dealer
# 299     city  2017.0         11.50         12.50   9000.0   Diesel     Dealer
# 300     brio  2016.0          5.30          5.90   5464.0   Petrol     Dealer
#
# ...

# %%
dfcar.drop(["CarName","FuelType","SellerType","Transmission"],axis=1,inplace=True)

# %%
dfcar
# Out:
#        Year  SellingPrice  PresentPrice      Kms  CarName_Activa 3g  \
# 0    2014.0          3.35          5.59  27000.0                  0
# 1    2013.0          4.75          9.54  43000.0                  0
# 2    2017.0          7.25          9.85   6900.0                  0
# 3    2011.0          2.85          4.15   5200.0                  0
# 4    2014.0          4.60          6.87  42450.0                  0
# ..      ...           ...           ...      ...                ...
# 296  2016.0          9.50         11.60  33988.0                  0
# 297  2015.0          4.00          5.90  60000.0                  0
# 298  2009.0          3.35         11.00  87934.0                  0
# 299  2017.0         11.50         12.50   9000.0                  0
# 300  2016.0          5.30          5.90   5464.0                  0
#
#      CarName_Activa 4g  CarName_Bajaj  ct 100  CarName_Bajaj Avenger 150  \
# 0                    0                      0                          0
# ...

# %%
X=dfcar.drop("SellingPrice",axis=1)

# %%
X
# Out:
#        Year  PresentPrice      Kms  CarName_Activa 3g  CarName_Activa 4g  \
# 0    2014.0          5.59  27000.0                  0                  0
# 1    2013.0          9.54  43000.0                  0                  0
# 2    2017.0          9.85   6900.0                  0                  0
# 3    2011.0          4.15   5200.0                  0                  0
# 4    2014.0          6.87  42450.0                  0                  0
# ..      ...           ...      ...                ...                ...
# 296  2016.0         11.60  33988.0                  0                  0
# 297  2015.0          5.90  60000.0                  0                  0
# 298  2009.0         11.00  87934.0                  0                  0
# 299  2017.0         12.50   9000.0                  0                  0
# 300  2016.0          5.90   5464.0                  0                  0
#
#      CarName_Bajaj  ct 100  CarName_Bajaj Avenger 150  \
# ...

# %%
y=dfcar["SellingPrice"]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: SellingPrice, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=2)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((301, 104), (240, 104), (61, 104))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((301,), (240,), (61,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg=LinearRegression()

# %%
lreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lreg.score(X_test,y_test)
# Out:
# 0.6388523813689219

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree=DecisionTreeRegressor()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(X_test,y_test)
# Out:
# 0.927457536000942

# %%
from sklearn.svm import SVR

# %%
svm_model=SVR()

# %%
svm_model.fit(X_train,y_train)
# Out:
# SVR()

# %%
svm_model.score(X_test,y_test)
# Out:
# -0.038272308598476634

# %%
from sklearn.ensemble import AdaBoostRegressor,RandomForestRegressor,GradientBoostingRegressor

# %%
ada=AdaBoostRegressor()

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
ada.score(X_test,y_test)
# Out:
# 0.9706479347171872

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(X_test,y_test)
# Out:
# 0.9750208735304409

# %%
gdr=GradientBoostingRegressor()

# %%
gdr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
gdr.score(X_test,y_test)
# Out:
# 0.9722521239247077

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor()

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
xgb.score(X_test,y_test)
# Out:
# 0.9791329310518149

# %% [markdown]
# Auto ml

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
dtree1=DecisionTreeRegressor()
svm1=SVR()
rfr1=RandomForestRegressor()
ada1=AdaBoostRegressor()
grad1=GradientBoostingRegressor()
xgb1=XGBRegressor()
lreg1=LinearRegression()
clist=[dtree1,svm1,rfr1,ada1,grad1,xgb1,lreg1]

# %%
clist
# Out:
# [DecisionTreeRegressor(),
#  SVR(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor(),
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  LinearRegression()]

# %%
import time
for i in clist:
    print(i,end="==>")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    print(m)
    time.sleep(0.6)
# Out:
# DecisionTreeRegressor()==>0.9294246448783194
# SVR()==>-0.038272308598476634
# RandomForestRegressor()==>0.9719681613019304
# AdaBoostRegressor()==>0.9640136418676849
# GradientBoostingRegressor()==>0.9765352264312868
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
# ...

# %%
rlist=[]
for i in range (0,51):
    print("random_state=",i)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
    for m in clist:
        print(m,end="==>")
        m.fit(X_train,y_train)
        s=m.score(X_test,y_test)
        print(s)
        rlist.append(s)
    print(rlist) 
    print("##########################################################################")
    print("Max =",max(rlist)) 
    rlist.index(max(rlist))
    print("Max_index=",rlist.index(max(rlist)))
    print("&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&")
# Out:
# random_state= 0
# DecisionTreeRegressor()==>0.8134890975477935
# SVR()==>-0.21289944565810415
# RandomForestRegressor()==>0.9744538574516466
# AdaBoostRegressor()==>0.9637573841749518
# GradientBoostingRegressor()==>0.9691210723427526
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
# ...
