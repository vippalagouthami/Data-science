# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dfwh=pd.read_csv("C:\\Users\\Legion\\OneDrive\\Desktop\\data\\linear regression\\Weight-height (1).csv")

# %%
dfwh
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
dfwh.isna().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
plt.boxplot(dfwh["Height"])
plt.show()

# %%
plt.boxplot(dfwh["Weight"])
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(dfwh["Height"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18084\398637354.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwh["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
dfwh["Height"].skew()
# Out:
# 0.04936908937689031

# %%
plt.hist(dfwh["Height"],bins=10,ec="yellow")
# Out:
# (array([  23.,  218.,  926., 1906., 2196., 2167., 1612.,  765.,  163.,
#           24.]),
#  array([54.26313333, 56.73669423, 59.21025513, 61.68381603, 64.15737693,
#         66.63093784, 69.10449874, 71.57805964, 74.05162054, 76.52518144,
#         78.99874235]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(dfwh["Height"])

# %%
m = dfwh["Height"].mean()

# %%
m
# Out:
# 66.36755975482124

# %%
s=dfwh["Height"].std()

# %%
s
# Out:
# 3.8475281207732324

# %%
lower=m-3*s

# %%
lower
# Out:
# 54.82497539250154

# %%
upper=m+3*s

# %%
upper
# Out:
# 77.91014411714094

# %%
dfwh[dfwh["Height"]<lower]
# Out:
#       Gender     Height     Weight
# 6624  Female  54.616858  71.393749
# 9285  Female  54.263133  64.700127

# %%
dfwh[dfwh["Height"]>upper]
# Out:
#      Gender     Height      Weight
# 994    Male  78.095867  255.690835
# 1317   Male  78.462053  227.342565
# 2014   Male  78.998742  269.989699
# 3285   Male  78.528210  253.889004
# 3757   Male  78.621374  245.733783

# %%
dfwh[(dfwh["Height"]<lower)|(dfwh["Height"]>upper)]
# Out:
#       Gender     Height      Weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 9285  Female  54.263133   64.700127

# %%
dfwh["Height"].map(lambda x: lower if x<lower else upper if x>upper else x)
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
dfwh["Height"]=dfwh["Height"].map(lambda x: lower if x<lower else upper if x>upper else x)

# %%
dfwh["Height"]
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
dfwh[(dfwh["Height"]<lower)|(dfwh["Height"]>upper)]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight]
# Index: []

# %%
dfwh["Weight"].skew()
# Out:
# 0.03295450444592437

# %%
plt.boxplot(dfwh["Weight"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2dbbf4e2230>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2dbbf4e2770>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2dbbf4e1f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2dbbf4e2cb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2dbbf4e2f50>],
#  'means': []}

# %%
plt.hist(dfwh["Weight"],bins=10,ec="yellow")
# Out:
# (array([  15.,  278., 1241., 2175., 1849., 2016., 1747.,  598.,   71.,
#           10.]),
#  array([ 64.70012671,  85.22908389, 105.75804107, 126.28699825,
#         146.81595543, 167.34491261, 187.87386979, 208.40282697,
#         228.93178415, 249.46074133, 269.98969851]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(dfwh["Weight"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_18084\210603827.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwh["Weight"])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
m1=dfwh["Weight"].mean()

# %%
m1
# Out:
# 161.44035683283076

# %%
s1=dfwh["Weight"].std()

# %%
s1
# Out:
# 32.108439006519546

# %%
low=m1-3*s1

# %%
low
# Out:
# 65.11503981327212

# %%
up=m1+3*s1

# %%
up
# Out:
# 257.7656738523894

# %%
dfwh[dfwh["Weight"]<low]
# Out:
#       Gender     Height     Weight
# 9285  Female  54.824975  64.700127

# %%
dfwh[dfwh["Weight"]>up]
# Out:
#      Gender     Height      Weight
# 2014   Male  77.910144  269.989699

# %%
dfwh[(dfwh["Weight"]<low)|(dfwh["Weight"]>up)]
# Out:
#       Gender     Height      Weight
# 2014    Male  77.910144  269.989699
# 9285  Female  54.824975   64.700127

# %%
dfwh["Weight"].map(lambda x : low if x<low else up if x>up else x)
# Out:
# 0       241.893563
# 1       162.310473
# 2       212.740856
# 3       220.042470
# 4       206.349801
#            ...
# 9995    136.777454
# 9996    170.867906
# 9997    128.475319
# 9998    163.852461
# 9999    113.649103
# Name: Weight, Length: 10000, dtype: float64

# %%
dfwh["Weight"]=dfwh["Weight"].map(lambda x : low if x<low else up if x>up else x)

# %%
dfwh
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
dfwh[(dfwh["Weight"]<low)|(dfwh["Weight"]>up)]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight]
# Index: []

# %% [markdown]
# encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(dfwh[["Gender"]])
# Out:
# OneHotEncoder()

# %%
ohe.transform(dfwh[["Gender"]])
# Out:
# <10000x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10000 stored elements in Compressed Sparse Row format>

# %%
a=ohe.transform(dfwh[["Gender"]]).toarray()

# %%
a
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]])

# %%
ohe.categories_
# Out:
# [array(['Female', 'Male'], dtype=object)]

# %%
dfohe=pd.DataFrame(a,columns=['Female', 'Male'],dtype="int")

# %%
dfohe
# Out:
#       Female  Male
# 0          0     1
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 9995       1     0
# 9996       1     0
# 9997       1     0
# 9998       1     0
# 9999       1     0
#
# [10000 rows x 2 columns]

# %%
dfwh=pd.concat([dfwh,dfohe],axis=1)

# %%
dfwh
# Out:
#       Gender     Height      Weight  Female  Male
# 0       Male  73.847017  241.893563       0     1
# 1       Male  68.781904  162.310473       0     1
# 2       Male  74.110105  212.740856       0     1
# 3       Male  71.730978  220.042470       0     1
# 4       Male  69.881796  206.349801       0     1
# ...      ...        ...         ...     ...   ...
# 9995  Female  66.172652  136.777454       1     0
# 9996  Female  67.067155  170.867906       1     0
# 9997  Female  63.867992  128.475319       1     0
# 9998  Female  69.034243  163.852461       1     0
# 9999  Female  61.944246  113.649103       1     0
#
# [10000 rows x 5 columns]

# %%
dfwh.drop("Gender",axis=1,inplace=True)

# %%
dfwh
# Out:
#          Height      Weight  Female  Male
# 0     73.847017  241.893563       0     1
# 1     68.781904  162.310473       0     1
# 2     74.110105  212.740856       0     1
# 3     71.730978  220.042470       0     1
# 4     69.881796  206.349801       0     1
# ...         ...         ...     ...   ...
# 9995  66.172652  136.777454       1     0
# 9996  67.067155  170.867906       1     0
# 9997  63.867992  128.475319       1     0
# 9998  69.034243  163.852461       1     0
# 9999  61.944246  113.649103       1     0
#
# [10000 rows x 4 columns]

# %%
X=dfwh.drop("Weight",axis=1)

# %%
X
# Out:
#          Height  Female  Male
# 0     73.847017       0     1
# 1     68.781904       0     1
# 2     74.110105       0     1
# 3     71.730978       0     1
# 4     69.881796       0     1
# ...         ...     ...   ...
# 9995  66.172652       1     0
# 9996  67.067155       1     0
# 9997  63.867992       1     0
# 9998  69.034243       1     0
# 9999  61.944246       1     0
#
# [10000 rows x 3 columns]

# %%
y=dfwh["Weight"]

# %%
y
# Out:
# 0       241.893563
# 1       162.310473
# 2       212.740856
# 3       220.042470
# 4       206.349801
#            ...
# 9995    136.777454
# 9996    170.867906
# 9997    128.475319
# 9998    163.852461
# 9999    113.649103
# Name: Weight, Length: 10000, dtype: float64

# %% [markdown]
# splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((10000, 3), (8000, 3), (2000, 3))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((10000,), (8000,), (2000,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg=LinearRegression()

# %%
lreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lreg.score(X_test,y_test)
# Out:
# 0.9037392172550384

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRFRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
dtree1=DecisionTreeRegressor()
svm1=SVR()
xgb1=XGBRFRegressor()
lreg1=LinearRegression()
rfr1=RandomForestRegressor()
ada1=AdaBoostRegressor()
grad=GradientBoostingRegressor()
clist=[dtree1,svm1,xgb1,lreg1,rfr1,ada1,grad]
clist
# Out:
# [DecisionTreeRegressor(),
#  SVR(),
#  XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='reg:squarederror', predictor=None, random_state=None,
#                 reg_alpha=None, ...),
#  LinearRegression(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor()]

# %%
import time 
for i in clist:
    print(i,end="==>|")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    print(m)
    time.sleep(1)
# Out:
# DecisionTreeRegressor()==>|0.8198311410235568
# SVR()==>|0.8525435241704692
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
#                reg_alpha=None, ...)==>|0.843989245877346
# LinearRegression()==>|0.9037392172550384
# RandomForestRegressor()==>|0.8658673420480294
# ...

# %%
rlist=[]
for i in range(0,100):
    print("Random_state=",i)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
    for j in clist:
        print(j,end="==>")
        j.fit(X_train,y_train)
        s=j.score(X_test,y_test)
        print(s)
        rlist.append(s)
    print(rlist)
    print("-------------------------------------------------------------------------")
    print("max=",max(rlist))
    rlist.index(max(rlist))
    print("max_index",rlist.index(max(rlist)))
    print("--------------------------------------------------------------------------------")
# Out:
# Random_state= 0
# DecisionTreeRegressor()==>0.8096892643061544
# SVR()==>0.8542829256782758
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
#                reg_alpha=None, ...)==>0.8383725110364334
# LinearRegression()==>0.9052605198714274
# ...
