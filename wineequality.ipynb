# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfwine=pd.read_csv(r"C:\Users\Legion\OneDrive\Desktop\data\winequality-red.csv")

# %%
dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dfwine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.boxplot(dfwine)
plt.xticks(rotation=90)
plt.show()

# %%
dfwine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.boxplot(dfwine["fixed acidity"])
# Out:
# <Axes: >

# %%
sns.distplot(dfwine["fixed acidity"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2516\1838865127.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwine["fixed acidity"])
# <Axes: xlabel='fixed acidity', ylabel='Density'>

# %%
dfwine["fixed acidity"].skew()
# Out:
# 0.9827514413284587

# %%
q1=dfwine["fixed acidity"].quantile(0.25)

# %%
q1
# Out:
# 7.1

# %%
q3=dfwine["fixed acidity"].quantile(0.75)

# %%
q3
# Out:
# 9.2

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 2.0999999999999996

# %%
l=q1-1.5*IQR

# %%
l
# Out:
# 3.95

# %%
u=q3+1.5*IQR

# %%
u
# Out:
# 12.349999999999998

# %%
dfwine[dfwine["fixed acidity"]<l]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
dfwine[dfwine["fixed acidity"]>u]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 205            12.8             0.300         0.74             2.6      0.095
# 206            12.8             0.300         0.74             2.6      0.095
# 243            15.0             0.210         0.44             2.2      0.075
# 244            15.0             0.210         0.44             2.2      0.075
# 264            12.5             0.560         0.49             2.4      0.064
# 294            13.3             0.340         0.52             3.2      0.094
# 328            13.4             0.270         0.62             2.6      0.082
# 338            12.4             0.490         0.58             3.0      0.103
# 339            12.5             0.280         0.54             2.3      0.082
# 347            13.8             0.490         0.67             3.0      0.093
# 353            13.5             0.530         0.79             4.8      0.120
# ...

# %%
dfwine[(dfwine["fixed acidity"]<l)|(dfwine["fixed acidity"]>u)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 205            12.8             0.300         0.74             2.6      0.095
# 206            12.8             0.300         0.74             2.6      0.095
# 243            15.0             0.210         0.44             2.2      0.075
# 244            15.0             0.210         0.44             2.2      0.075
# 264            12.5             0.560         0.49             2.4      0.064
# 294            13.3             0.340         0.52             3.2      0.094
# 328            13.4             0.270         0.62             2.6      0.082
# 338            12.4             0.490         0.58             3.0      0.103
# 339            12.5             0.280         0.54             2.3      0.082
# 347            13.8             0.490         0.67             3.0      0.093
# 353            13.5             0.530         0.79             4.8      0.120
# ...

# %%
dfwine["fixed acidity"].map(lambda x:l if x<l else u if x>u else x)
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
dfwine["fixed acidity"]=dfwine["fixed acidity"].map(lambda x:l if x<l else u if x>u else x)

# %%
dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dfwine[(dfwine["fixed acidity"]<l)|(dfwine["fixed acidity"]>u)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
plt.boxplot(dfwine["volatile acidity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2e89fdf60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d2e89fe4a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2e89fdcc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2e89fe9e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2e89fec80>],
#  'means': []}

# %%
sns.distplot(dfwine["volatile acidity"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2516\1258072585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwine["volatile acidity"])
# <Axes: xlabel='volatile acidity', ylabel='Density'>

# %%
dfwine["volatile acidity"].skew()
# Out:
# 0.6715925723840199

# %%
q11=dfwine["volatile acidity"].quantile(0.25)

# %%
q11
# Out:
# 0.39

# %%
q31=dfwine["volatile acidity"].quantile(0.75)

# %%
q31
# Out:
# 0.64

# %%
IQR=q31-q11

# %%
IQR
# Out:
# 0.25

# %%
l1=q11-1.5*IQR

# %%
l1
# Out:
# 0.015000000000000013

# %%
u1=q31+1.5*IQR

# %%
u1
# Out:
# 1.0150000000000001

# %%
dfwine[(dfwine["volatile acidity"]<l1)|(dfwine["volatile acidity"]>u1)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 38              5.7             1.130         0.09            1.50      0.172
# 94              5.0             1.020         0.04            1.40      0.045
# 120             7.3             1.070         0.09            1.70      0.178
# 126             8.2             1.330         0.00            1.70      0.081
# 127             8.1             1.330         0.00            1.80      0.082
# 134             7.9             1.040         0.05            2.20      0.084
# 199             6.9             1.090         0.06            2.10      0.061
# 553             5.0             1.040         0.24            1.60      0.050
# 672             9.8             1.240         0.34            2.00      0.079
# 690             7.4             1.185         0.00            4.25      0.097
# 700            10.6             1.020         0.43            2.90      0.076
# ...

# %%
dfwine["volatile acidity"]=dfwine["volatile acidity"].map(lambda x: l1 if x<l1 else u1 if x>u1 else x)

# %%
dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dfwine[(dfwine["volatile acidity"]<l1)|(dfwine["volatile acidity"]>u1)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# error detection on citric acid

# %%
sns.boxplot(dfwine["citric acid"])
# Out:
# <Axes: >

# %%
sns.distplot(dfwine["citric acid"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2516\306841669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwine["citric acid"])
# <Axes: xlabel='citric acid', ylabel='Density'>

# %%
dfwine["citric acid"].skew()
# Out:
# 0.3183372952546368

# %%
m=dfwine["citric acid"].mean()
s=dfwine["citric acid"].std()

# %%
l2=m-3*s
u2=m+3*s

# %%
dfwine[(dfwine["citric acid"]<l2)|(dfwine["citric acid"]>u2)]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 151            9.2              0.52          1.0             3.4       0.61
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 151                 32.0                  69.0   0.9996  2.74        2.0
#
#      alcohol  quality
# 151      9.4        4

# %%
dfwine["citric acid"]=dfwine["citric acid"].map(lambda x :l2 if x<l2 else u2 if x>u2 else x)

# %%
dfwine[(dfwine["citric acid"]<l2)|(dfwine["citric acid"]>u2)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# error detection on residual sugar

# %%
sns.boxplot(dfwine["residual sugar"])
# Out:
# <Axes: >

# %%
sns.distplot(dfwine["residual sugar"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2516\2497327031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwine["residual sugar"])
# <Axes: xlabel='residual sugar', ylabel='Density'>

# %%
dfwine["residual sugar"].skew()
# Out:
# 4.54065542590319

# %%
q11=dfwine["residual sugar"].quantile(0.25)
q31=dfwine["residual sugar"].quantile(0.75)

# %%
IQR=q31-q11

# %%
l3=q11-1.5*IQR
u3=q31+1.5*IQR

# %%
dfwine[(dfwine["residual sugar"]<l3)|(dfwine["residual sugar"]>u3)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 18              7.4             0.590         0.08             4.4      0.086
# ...             ...               ...          ...             ...        ...
# 1552            6.3             0.680         0.01             3.7      0.103
# 1558            6.9             0.630         0.33             6.7      0.235
# 1574            5.6             0.310         0.78            13.9      0.074
# 1577            6.2             0.700         0.15             5.1      0.076
# 1589            6.6             0.725         0.20             7.8      0.073
#
# ...

# %%
dfwine["residual sugar"]=dfwine["residual sugar"].map(lambda x:l3 if x<l3 else u3 if x>u3 else x )

# %%
dfwine[(dfwine["residual sugar"]<l3)|(dfwine["residual sugar"]>u3)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# error detection on chlorides columns

# %%
sns.boxplot(dfwine["chlorides"])
# Out:
# <Axes: >

# %%
sns.distplot(dfwine["chlorides"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2516\454121523.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfwine["chlorides"])
# <Axes: xlabel='chlorides', ylabel='Density'>

# %%
dfwine["chlorides"].skew()
# Out:
# 5.680346571971722
