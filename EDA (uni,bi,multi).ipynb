# %%
import pandas as pd

# %%
import numpy as np

# %%
dfs=pd.read_csv("C:\\Users\\Legion\\OneDrive\\Desktop\\supermarket_sales.csv",parse_dates=["Date"])

# %%
dfs
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
dfs.dtypes=="object"
# Out:
# Invoice ID                  True
# Branch                      True
# City                        True
# Customer type               True
# Gender                      True
# Product line                True
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                        True
# Payment                     True
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %%
dfs.dtypes[dfs.dtypes=="object"]
# Out:
# Invoice ID       object
# Branch           object
# City             object
# Customer type    object
# Gender           object
# Product line     object
# Time             object
# Payment          object
# dtype: object

# %%
dfs.dtypes!=object
# Out:
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                  True
# Quantity                    True
# Tax 5%                      True
# Total                       True
# Date                        True
# Time                       False
# Payment                    False
# cogs                        True
# gross margin percentage     True
# gross income                True
# Rating                      True
# dtype: bool

# %%
dfs.dtypes[dfs.dtypes!=object]
# Out:
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
dfs.dtypes[dfs.dtypes!="object"].describe()
# Out:
# count           9
# unique          3
# top       float64
# freq            7
# dtype: object

# %%
dfs.dtypes[dfs.dtypes!="object"].index
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
dfs[['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating']]
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ...

# %%
dfs[['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating']].describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# 1) find aggregate sales among branches(categorical columns)

# %%
dfs.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dfs.groupby("Branch")

# %%
gb_branch=dfs.groupby("Branch")

# %%
gb_branch

# %%
for i,j in gb_branch:
    print(i)
    print()
    print(j)
    print()
    print("***********************************")
# Out:
# A
#
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
for i,j in gb_branch:
    print(i)
    print()
    print(j["Total"])
    print()
    print("***********************************")
# Out:
# A
#
# 0      548.9715
# 2      340.5255
# 3      489.0480
# 4      634.3785
# 6      433.6920
#          ...
# 990    296.9400
# 992    121.8630
# 997     33.4320
# 998     69.1110
# 999    649.2990
# Name: Total, Length: 340, dtype: float64
#
# ***********************************
# B
#
# 9       172.746
# 10       60.816
# 11      107.142
# 15      590.436
# 19       84.630
#          ...
# 987     520.800
# 989     633.108
# 991     804.300
# 993     183.645
# 996    1022.490
# Name: Total, Length: 332, dtype: float64
#
# ***********************************
# C
#
# 1       80.2200
# 5      627.6165
# 7      772.3800
# 20     451.7100
# 34     417.5640
#          ...
# 983    734.7060
# 984    708.3195
# 988    864.5700
# 994     63.9975
# 995     42.3675
# Name: Total, Length: 328, dtype: float64
#
# ***********************************

# %%
for i,j in gb_branch:
    print(i)
    print()
    print(j["Total"].sum())
    print()
    print("***********************************")
# Out:
# A
#
# 106200.3705
#
# ***********************************
# B
#
# 106197.67199999999
#
# ***********************************
# C
#
# 110568.7065
#
# ***********************************

# %%
gb_branch["Total"].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
dfs["Branch"]
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
dfs["Branch"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
dfs["Branch"].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
dfs.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dfs["Payment"]
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
dfs["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
dfs.groupby("Payment")

# %%
gb_payment=dfs.groupby("Payment")

# %%
gb_payment

# %%
gb_payment["Total"].sum()
# Out:
# Payment
# Cash           112206.570
# Credit card    100767.072
# Ewallet        109993.107
# Name: Total, dtype: float64

# %%
gb_payment["Total"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='Total'>

# %%
gb_payment["Total"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Payment'>

# %%
dfs["Payment"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.hist(dfs["Payment"],bins=20)#numerical colum
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(dfs["Total"],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(dfs["Total"],bins=20,rwidth=90,edgecolor="r",color="y")#categorical column
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# displot

# %%
sns.displot(dfs["Payment"])

# %%
sns.distplot(dfs["Total"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\3563039909.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["Total"])
# <Axes: xlabel='Total', ylabel='Density'>

# %%
from scipy .stats import norm

# %%
sns.distplot(dfs["Total"],fit=norm)
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\1370868445.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["Total"],fit=norm)
# <Axes: xlabel='Total', ylabel='Density'>

# %% [markdown]
# Count Plot

# %%
sns.countplot(x="Payment",data=dfs)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
sns.boxplot(dfs["Total"])
# Out:
# <Axes: >

# %%
dfs["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
plt.pie(dfs["Payment"].value_counts(),labels=['Ewallet', 'Cash', 'Credit card'])
plt.show()

# %%
sns.countplot(x=dfs['Branch'])
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
sns.countplot(x='Branch',data=dfs)
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
dfs["Branch"].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
dfs["Branch"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Branch'>

# %%
dfs["Branch"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
dfs["Branch"].value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='Branch'>

# %%
plt.hist(dfs["Branch"])
plt.show()

# %%
sns.displot(dfs["Branch"])

# %%
sns.distplot(dfs["Branch"])#error
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\2462261753.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["Branch"])#error
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.distplot(dfs["Branch"])
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# ...

# %% [markdown]
# most popular payments method used by customer (categorial columns)

# %%
dfs.groupby("Payment")

# %%
gb_payment=dfs.groupby("Payment")

# %%
gb_payment

# %%
gb_payment["Payment"].value_counts()
# Out:
# Payment      Payment
# Cash         Cash           344
# Credit card  Credit card    311
# Ewallet      Ewallet        345
# Name: Payment, dtype: int64

# %%
gb_payment["Payment"].value_counts().max()
# Out:
# 345

# %%
x=dfs["Payment"].value_counts()

# %%
x
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
x.max()
# Out:
# 345

# %%
x==x.max()
# Out:
# Ewallet         True
# Cash           False
# Credit card    False
# Name: Payment, dtype: bool

# %%
x[x==x.max()]
# Out:
# Ewallet    345
# Name: Payment, dtype: int64

# %%
dfs.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dfs.groupby("Product line")

# %%
gb_productline=dfs.groupby("Product line")

# %%
gb_productline

# %%
dfs['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
gb_productline["Product line"].value_counts()
# Out:
# Product line            Product line
# Electronic accessories  Electronic accessories    170
# Fashion accessories     Fashion accessories       178
# Food and beverages      Food and beverages        174
# Health and beauty       Health and beauty         152
# Home and lifestyle      Home and lifestyle        160
# Sports and travel       Sports and travel         166
# Name: Product line, dtype: int64

# %%
gb_productline["Product line"].value_counts().max()
# Out:
# 178

# %%
y=dfs['Product line'].value_counts()

# %%
y
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
y.max()
# Out:
# 178

# %%
y==y.max()
# Out:
# Fashion accessories        True
# Food and beverages        False
# Electronic accessories    False
# Sports and travel         False
# Home and lifestyle        False
# Health and beauty         False
# Name: Product line, dtype: bool

# %%
y[y==y.max()]
# Out:
# Fashion accessories    178
# Name: Product line, dtype: int64

# %%
gb_productline["Product line"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Product line,Product line'>

# %%
gb_productline["Product line"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Product line'>

# %%
plt.hist(x='Product line',data=dfs)
plt.show()

# %%
sns.displot(dfs['Product line'])

# %%
sns.countplot(x="Product line",data=dfs)
plt.xticks(rotation=90)
plt.show()

# %%
sns.violinplot(x="Product line",y="Total",data=dfs)
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(dfs['Product line'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\1590271297.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs['Product line'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 sns.distplot(dfs['Product line'])
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
# ...

# %% [markdown]
# customer rating distribution

# %%
dfs.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dfs['Rating']
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
plt.hist(dfs["Rating"])
plt.show()

# %%
dfs['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
np.round(dfs['Rating'].skew())
# Out:
# 0.0

# %%
plt.hist(dfs['Rating'],bins=100)
# Out:
# (array([11., 17.,  0., 22.,  0., 18., 17.,  0., 17.,  0.,  8., 12.,  0.,
#         13.,  0., 18., 21.,  0., 21.,  0., 15., 11.,  0., 14.,  0., 19.,
#         16.,  0., 14.,  0., 14., 17.,  0., 26.,  0., 14., 21.,  0., 15.,
#          0., 16., 21.,  0., 24.,  0., 19., 13.,  0., 15.,  0., 20., 16.,
#          0., 18.,  0., 18., 16.,  0., 13.,  0., 20., 18.,  0., 15.,  0.,
#         18., 21.,  0., 13.,  0., 14., 11.,  0., 18.,  0., 18., 18.,  0.,
#         20.,  0., 14., 16.,  0., 15.,  0., 14., 16.,  0., 16.,  0., 12.,
#         22.,  0., 17.,  0., 14., 19.,  0., 16.,  5.]),
#  array([ 4.  ,  4.06,  4.12,  4.18,  4.24,  4.3 ,  4.36,  4.42,  4.48,
#          4.54,  4.6 ,  4.66,  4.72,  4.78,  4.84,  4.9 ,  4.96,  5.02,
#          5.08,  5.14,  5.2 ,  5.26,  5.32,  5.38,  5.44,  5.5 ,  5.56,
#          5.62,  5.68,  5.74,  5.8 ,  5.86,  5.92,  5.98,  6.04,  6.1 ,
#          6.16,  6.22,  6.28,  6.34,  6.4 ,  6.46,  6.52,  6.58,  6.64,
# ...

# %%
sns.distplot(dfs["Rating"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\1923975236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["Rating"])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
from scipy.stats import norm

# %%
sns.distplot(dfs["Rating"],fit=norm)
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\1199461328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["Rating"],fit=norm)

# %%
sns.displot(dfs["Rating"])
plt.show()

# %% [markdown]
# find the distribution of COGS

# %%
dfs["cogs"]
# Out:
# 0      522.83
# 1       76.40
# 2      324.31
# 3      465.76
# 4      604.17
#         ...
# 995     40.35
# 996    973.80
# 997     31.84
# 998     65.82
# 999    618.38
# Name: cogs, Length: 1000, dtype: float64

# %%
dfs["cogs"].dtype
# Out:
# dtype('float64')

# %%
plt.hist(dfs["cogs"])
plt.show()

# %%
dfs["cogs"].skew()
# Out:
# 0.8925698049581418

# %%
np.round(dfs["cogs"].skew())
# Out:
# 1.0

# %%
plt.hist(dfs["cogs"],bins=50)
plt.show()

# %%
sns.distplot(dfs["cogs"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\2789925504.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["cogs"])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
sns.distplot(dfs["cogs"],fit=norm)
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\224177494.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs["cogs"],fit=norm)
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
sns.boxplot(dfs["cogs"])
# Out:
# <Axes: >

# %%
sns.displot(dfs["cogs"])

# %%
sns.boxplot(x=dfs["cogs"])
# Out:
# <Axes: xlabel='cogs'>

# %% [markdown]
# bivariate/multivariate

# %%
sns.scatterplot(x="cogs",y="Rating",data=dfs)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# Does cogs effects gross income

# %%
plt.scatter(dfs["cogs"],dfs["gross income"])

# %%
sns.scatterplot(x=dfs["cogs"],y=dfs["gross income"])
# Out:
# <Axes: xlabel='cogs', ylabel='gross income'>

# %%
sns.scatterplot(x=dfs["gross income"],y=dfs["Rating"])
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# most profitable bacnchas per gross income(num-cat)

# %%
dfs["Branch"]
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
dfs["Branch"].dtype
# Out:
# dtype('O')

# %%
dfs['gross income'].dtype
# Out:
# dtype('float64')

# %%
sns.barplot(x='Branch',y='gross income',data=dfs)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x="gross income",y='Branch',data=dfs)
# Out:
# <Axes: xlabel='gross income', ylabel='Branch'>

# %%
sns.barplot(data=dfs,x="Branch",y="Rating")
# Out:
# <Axes: xlabel='Branch', ylabel='Rating'>

# %%
sns.barplot(data=dfs,x="Branch",y="Rating",hue="Gender")
# Out:
# <Axes: xlabel='Branch', ylabel='Rating'>

# %%
sns.barplot(data=dfs,x="Branch",y="gross income",hue="Gender")
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data=dfs,x="Payment",y="gross income")
# Out:
# <Axes: xlabel='Payment', ylabel='gross income'>

# %%
sns.barplot(data=dfs,x="Payment",y="gross income",hue="Gender")
# Out:
# <Axes: xlabel='Payment', ylabel='gross income'>

# %%
sns.barplot(data=dfs,x="Payment",y="gross income",hue="City")
# Out:
# <Axes: xlabel='Payment', ylabel='gross income'>

# %%
sns.violinplot(data=dfs,x="Payment",y="gross income")
# Out:
# <Axes: xlabel='Payment', ylabel='gross income'>

# %%
sns.violinplot(data=dfs,x="Payment",y="gross income",hue="Gender")
# Out:
# <Axes: xlabel='Payment', ylabel='gross income'>

# %%
sns.boxplot(data=dfs,x="Branch",y="gross income",hue="Gender")
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data=dfs,x="Gender",y="gross income",hue="City")
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# find the product line generates most income

# %%
dfs["Product line"]
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
sns.barplot(x="Product line",y="gross income",data=dfs)
# Out:
# <Axes: xlabel='Product line', ylabel='gross income'>

# %%
sns.barplot(x="Product line",y="gross income",data=dfs)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
dfs.groupby("Product line")

# %%
dfs.groupby("Product line")["gross income"]

# %%
dfs.groupby("Product line")["gross income"].sum()
# Out:
# Product line
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Food and beverages        2673.5640
# Health and beauty         2342.5590
# Home and lifestyle        2564.8530
# Sports and travel         2624.8965
# Name: gross income, dtype: float64

# %%
dfs.groupby("Product line")["gross income"].max()
# Out:
# Product line
# Electronic accessories    44.8785
# Fashion accessories       49.6500
# Food and beverages        49.2600
# Health and beauty         45.2500
# Home and lifestyle        48.7500
# Sports and travel         47.7200
# Name: gross income, dtype: float64

# %%
dfs.groupby("Product line")["gross income"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# find the heighest unit price in product line(num - cat)

# %%
dfs["Unit price"].dtype
# Out:
# dtype('float64')

# %%
sns.boxplot(data=dfs,x="Product line",y ="Unit price" )
# Out:
# <Axes: xlabel='Product line', ylabel='Unit price'>

# %%
sns.barplot(data=dfs,x="Product line",y ="Unit price",hue="City" )
# Out:
# <Axes: xlabel='Product line', ylabel='Unit price'>

# %%
sns.barplot(data=dfs,x="Product line",y ="Unit price" )
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
sns.boxplot(data=dfs,x="Product line",y="Unit price",hue="City")
# Out:
# <Axes: xlabel='Product line', ylabel='Unit price'>

# %%
sns.violinplot(data=dfs,x="Product line",y="Unit price",hue="City")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# find different payment methods used by customers citywise(cat-cat)

# %%
dfs["Payment"]
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
dfs["City"]
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
dfs["Payment"].dtype
# Out:
# dtype('O')

# %%
dfs["City"].dtype
# Out:
# dtype('O')

# %%
dfs.groupby('City')

# %%
dfs.groupby('City')["Payment"]

# %%
dfs.groupby('City')["Payment"].sum()
# Out:
# City
# Mandalay     Credit cardEwalletCashCashEwalletEwalletCredit...
# Naypyitaw    CashEwalletEwalletEwalletEwalletEwalletEwallet...
# Yangon       EwalletCredit cardEwalletEwalletEwalletCredit ...
# Name: Payment, dtype: object

# %%
dfs.groupby('City')["Payment"].value_counts()
# Out:
# City       Payment
# Mandalay   Ewallet        113
#            Cash           110
#            Credit card    109
# Naypyitaw  Cash           124
#            Ewallet        106
#            Credit card     98
# Yangon     Ewallet        126
#            Cash           110
#            Credit card    104
# Name: Payment, dtype: int64

# %%
df=pd.crosstab(index=dfs["City"],columns=dfs["Payment"])

# %%
df
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(df)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
sns.heatmap(df,linewidth=2)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
sns.heatmap(df,linewidth=2,linecolor='y')
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
sns.heatmap(df,linewidths=2,linecolor="y",annot=True)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
sns.heatmap(df,linewidths=2,linecolor="y",annot=True,fmt="d")
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
sns.heatmap(df,linewidths=2,linecolor="y",annot=True,fmt="d",cbar=False)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
dfs
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df1=pd.crosstab(index=dfs["Gender"],columns=dfs["Payment"])

# %%
df1
# Out:
# Payment  Cash  Credit card  Ewallet
# Gender
# Female    178          163      160
# Male      166          148      185

# %%
sns.heatmap(df1)
# Out:
# <Axes: xlabel='Payment', ylabel='Gender'>

# %%
sns.heatmap(df1,linewidths=2,linecolor="y",annot=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Gender'>

# %%
sns.heatmap(df1,linewidths=2,linecolor="y",annot=True,fmt='d')
# Out:
# <Axes: xlabel='Payment', ylabel='Gender'>

# %%
sns.heatmap(df1,linewidths=2,linecolor="y",annot=True,fmt="d",cbar=False)
# Out:
# <Axes: xlabel='Payment', ylabel='Gender'>

# %%
df2=pd.crosstab(index=dfs["Gender"],columns=dfs["Product line"],values=dfs["Total"],aggfunc="sum")

# %%
df2
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                    27102.0225            30437.400          33170.9175
# Male                      27235.5090            23868.495          22973.9265
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female               18560.9865          30036.8775         28574.7210
# Male                 30632.7525          23825.0355         26548.1055

# %%
sns.heatmap(df2)
# Out:
# <Axes: xlabel='Product line', ylabel='Gender'>

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df2,linewidths=2,linecolor='y',annot=True,fmt="f")
# Out:
# <Axes: xlabel='Product line', ylabel='Gender'>

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df2,linewidths=2,linecolor='y',annot=True,fmt="f")
plt.save(image.)
# Out:
#   Cell In[168], line 3
#     plt.save(image.)
#                    ^
# SyntaxError: invalid syntax

# %%
dfs.pivot_table(index="City",columns="Payment")
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\3964049458.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   dfs.pivot_table(index="City",columns="Payment")
#            Quantity                          Rating                        \
# Payment        Cash Credit card   Ewallet      Cash Credit card   Ewallet
# City
# Mandalay   5.709091    5.495413  5.247788  6.998182    6.760550  6.698230
# Naypyitaw  5.612903    5.540816  5.584906  6.973387    7.291837  6.986792
# Yangon     5.200000    5.576923  5.611111  6.938182    6.985577  7.138889
#
#               Tax 5%                              Total  ... Unit price  \
# Payment         Cash Credit card    Ewallet        Cash  ...    Ewallet
# City                                                     ...
# Mandalay   15.298468   16.314922  14.122779  321.267832  ...  53.450973
# ...

# %%
dfs.pivot_table(index="City",columns="Payment")["Quantity"]
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\699640286.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   dfs.pivot_table(index="City",columns="Payment")["Quantity"]
# Payment        Cash  Credit card   Ewallet
# City
# Mandalay   5.709091     5.495413  5.247788
# Naypyitaw  5.612903     5.540816  5.584906
# Yangon     5.200000     5.576923  5.611111

# %%
dfs.pivot_table(index="City",columns="Payment")["Quantity"].sum()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_15092\2303314328.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   dfs.pivot_table(index="City",columns="Payment")["Quantity"].sum()
# Payment
# Cash           16.521994
# Credit card    16.613152
# Ewallet        16.443804
# dtype: float64

# %%
 sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 sns.heatmap()
#
# TypeError: heatmap() missing 1 required positional argument: 'data'

# %% [markdown]
# which productline is purchased in large quantity

# %%
dfs["Product line"]
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
dfs["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
dfs["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
dfs["Quantity"]
# Out:
# 0       7
# 1       5
# 2       7
# 3       8
# 4       7
#        ..
# 995     1
# 996    10
# 997     1
# 998     1
# 999     7
# Name: Quantity, Length: 1000, dtype: int64

# %%
dfs["Quantity"].dtype
# Out:
# dtype('int64')

# %%
dfs["Quantity"].value_counts()# value_counts is appleied only for cat
# Out:
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: Quantity, dtype: int64

# %%
sns.boxplot(x=dfs["Product line"],y=dfs["Quantity"])
# Out:
# <Axes: xlabel='Product line', ylabel='Quantity'>

# %%
sns.boxplot(x=dfs["Product line"],y=dfs["Quantity"])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
dfs.groupby("Product line")

# %%
dfs.groupby("Product line")["Quantity"]

# %%
dfs.groupby("Product line")["Quantity"].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
dfs.groupby("Product line")["Quantity"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# display daily sales by day of week

# %%
dfs
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dfs["Date"]
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
dfs["Date"]
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
dfs["Date"].dt.day_name()
# Out:
# 0      Saturday
# 1        Friday
# 2        Sunday
# 3        Sunday
# 4        Friday
#          ...
# 995     Tuesday
# 996    Saturday
# 997    Saturday
# 998      Friday
# 999      Monday
# Name: Date, Length: 1000, dtype: object

# %%
dfs["Date"].dt.day_name()
# Out:
# 0      Saturday
# 1        Friday
# 2        Sunday
# 3        Sunday
# 4        Friday
#          ...
# 995     Tuesday
# 996    Saturday
# 997    Saturday
# 998      Friday
# 999      Monday
# Name: Date, Length: 1000, dtype: object

# %%
dfs["Date"].dt.month_name()
# Out:
# 0       January
# 1         March
# 2         March
# 3       January
# 4      February
#          ...
# 995     January
# 996       March
# 997    February
# 998    February
# 999    February
# Name: Date, Length: 1000, dtype: object

# %%
dfs["Month_Name"]=dfs["Date"].dt.month_name()

# %%
dfs["Days"]=dfs["Date"].dt.day_name()

# %%
dfs["Month_Name"].value_counts()
# Out:
# January     352
# March       345
# February    303
# Name: Month_Name, dtype: int64

# %%
dfs["Month_Name"].value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='Month_Name'>

# %%
dfs["Month_Name"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.barplot(x="Month_Name",y="gross income",data=dfs)
# Out:
# <Axes: xlabel='Month_Name', ylabel='gross income'>

# %%
dfs.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Month_Name', 'Days'],
#       dtype='object')

# %%
dfs
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# what will be highest month

# %%
dfs
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sns.barplot(x = "Month_Name", y = "gross income", data = dfs)
# Out:
# <Axes: xlabel='Month_Name', ylabel='gross income'>

# %% [markdown]
# which city has done the max sales in jan which product are sold in the jan

# %%
df3=pd.crosstab(index=dfs["City"],columns=dfs["Product line"])

# %%
df3
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# City
# Mandalay                          55                   62                  50
# Naypyitaw                         55                   65                  66
# Yangon                            60                   51                  58
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# City
# Mandalay                     53                  50                 62
# Naypyitaw                    52                  45                 45
# Yangon                       47                  65                 59
